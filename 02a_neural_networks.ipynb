# %% [markdown]
# # Music machine learning - Neural networks
#
# ### Author: Philippe Esling (esling@ircam.fr)
#
# In this course we will cover
# 1. A [quick introduction](#intro) on the code that we will adress and auxiliary functions
# 2. A simple implementation for a [single neuron](#single)
# 3. An implementation of [regression](#implem) using scikit-learn
# 4. Some [common good practices](#practices) in machine learning

# %% [markdown]
# # Introducing neural networks

# %% [markdown]
# In this tutorial, we will cover a more advanced classification algorithm through the use of *neural networks*. The tutorial starts by performing a simple **single neuron** discrimination of two random distributions. Then, we will study the typical **XOR problem** by using a more advanced 2-layer **perceptron**. Finally, we generalize the use of neural networks in order to perform classification on a given set of audio files.

# %% [markdown]
# We are going to use relatively _low-level_ libraries to perform the first exercises (implementing your own neurons)

# %%
import time
import numpy as np
# %matplotlib inline
from matplotlib import pyplot as plt

# %% [markdown]
# To simplify your work, we provide a first set of functions that provides simple plotting functionnalities (from the `helper_plot.py` file)
#
#   |**File**|*Explanation*|
#   |-------:|:---------|
#   |`plot_boundary`|Plots the decision boundary of a single neuron with 2-dimensional inputs|
#   |`plot_patterns`|Plots (bi-dimensionnal) input patterns|

# %%
from helper_plot import plot_boundary
from helper_plot import plot_patterns

# %% [markdown]
# Remember that a single neuron is only able to learn _linearly separable_ problems. To produce such classes of problems, we provide a script that draw a set of random 2-dimensional points, then choose a random line in this space that will act as the linear frontier between 2 classes (hence defining a linear 2-class problem). The variables that will be used by your code are the following.
#
# ```Matlab
# desired       % classes of the patterns
# inputs        % 2 x n final matrix of random input patterns
# weights       % 2 x 1 vector of neuron weights
# bias          % 1 x 1 vector of bias
# ```
#
# You can execute the code below to see our simple classification problem. (Note that running the same cell multiple times produces a different starting dataset).

# %%
# Number of points to generate
nPats = 30 + np.floor(np.random.rand() * 30);
# Generate 2-dimensional random points
patterns = np.random.rand(2, int(nPats)) * 2 - 1;
# Slope of separating line
slope = np.log(np.random.rand() * 10);
yint = np.random.rand() * 2 - 1;
# Create the indexes for a two-class problem
desired = (patterns[1,:] - patterns[0,:] * slope - yint > 0) * 1;
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired);

# %% [markdown]
# ## Single neuron
#
# For the first parts of the tutorial, we will perform the simplest classification model possible in a neural network setting, a single neuron. We briefly recall here that; given an input vector $ \mathbf{x} \in \mathbb{R}^{n} $, a single neuron computes the function
#
# $$
# \begin{equation}
# \hat{y}=\phi\left(\sum_{i = 1}^{n}w_{i}.x_{i} + b\right)
# %\label{eq1}
# \end{equation}
# $$
#
# with $ \mathbf{w} \in \mathbb{R}^{n} $ a weight vector, $ b $ a bias and $ \phi\left(\cdot\right) $ an *activation function*. Therefore, if we consider the *threshold* activation function ($ \phi_{0}\left(x\right)=1 $ if $ x \geq 0$), a single neuron simply performs an *affine transform* and then a *linear* discrimination of the space. A network will be composed of _layers_ of these neurons, which produce successive computations
#
# <img src="images/02_feedforward_nn.png" align="center"/>
#
# Geometrically, a single neuron computes an hyperplane that separates the space. In order to learn, we have to adjust the weights and know "how much wrong we are". To do so, we consider that we know the desired output $ d $ of a system for a given example $ \mathbf{x} $ (eg. a predicted value for a regression system, a class value for a classification system). Therefore, we define the loss function $ \mathcal{L}_{\mathcal{D}} $ over a whole dataset as
#
# $$
# \begin{equation}
# \mathcal{L}_{\mathcal{D}}=\sum_{j=1}^{k_{\mathcal{D}}}\left\Vert y_{j}-\hat{y}_{j}\right\Vert ^{2}
# %\label{eq2}
# \end{equation}
# $$
#
# In order to know how to change the weights based on the value of the errors, we need to now "how to change it to make it better". Therefore, we should compute the sets of derivatives of the error given each parameter
#
# $$
# \begin{equation}
# \Delta\bar{\mathbf{w}}=\left(\frac{\delta\mathcal{L}}{\delta w_{1}},\ldots,\frac{\delta\mathcal{L}}{\delta w_{n}}\right)
# %\label{eq3}
# \end{equation}
# $$
#
# ***
#
# **Exercise**
#
#   1. Perform the derivatives of the output given a single neuron
#   2. Perform the derivatives for the bias as well
#
# ***

# %% [markdown]
# ### Training your own neuron
#
# We will start by training a single neuron to learn how to perform this discrimination with a linear problem (so that a single neuron is enough to solve it).

# %%
# Inputs to use
inputs = patterns;
# Initialize the weights
weights = np.random.randn(1, 2);
bias = np.random.randn(1, 1)
# Learning rate
eta = 0.05;
# Weight decay
lambdaW = 0.3

# %% [markdown]
# Now you need to update the following code loop to ensure that your neuron learns to separate between the classes
# ***
#
# **Exercise**
#   1. Update the loop so that it computes the forward propagation error
#   2. Update the loop to perform learning (based on back-propagation)
#   3. Run the learning procedure, which should produce a result similar to that displayed on the website
#   4. Perform multiple re-runs by **tweaking the hyperparameters** (learning rate, weight decay)
#   5. What observations can you make on the learning process?
#   6. (Optional) Change the input patterns, and confirm your observations.
#   6. (Optional) Incorporate the bias in the weights to obtain a **vectorized** code.
#
# ***

# %%
# Plot the corresponding pattern
fig = plot_patterns(patterns,desired);
plt.draw()
# Update loop
for i in range(100):
    y_chap = weights @ inputs + bias    #Forward propagation

    y_chap = y_chap[0,:]
    #On applique la fonction seuil
    y_chap2 = (y_chap>=0)*1
    
    loss = np.sum(np.square(desired-y_chap2))
    print(loss)
    if loss == 0 :
        break

    weights += eta * np.matmul(desired-y_chap2, inputs.T)

    #Evolution du biais
    bias += eta * np.mean(desired-y_chap2)
    
    print('%2d.  weights = %f, %f, %f' % (i, bias[0, 0], weights[0, 0], weights[0, 1]))
    plot_boundary(np.concatenate((bias, weights), axis=1), i, '--', fig)
    plt.draw()
    #time.sleep(0.2)
plot_boundary(np.concatenate((bias, weights), axis=1), i, '-', fig);
# Out:
# 27
#  0.  weights = 0.790311, -0.365858, 1.107722
# 23
#  1.  weights = 0.768613, -0.905791, 1.047238
# 17
#  2.  weights = 0.752576, -1.320347, 0.859411
# 16
#  3.  weights = 0.737481, -1.670358, 0.697090
# 11
#  4.  weights = 0.727104, -1.816123, 0.677231
# 9
#  5.  weights = 0.718613, -1.903551, 0.701932
# 8
#  6.  weights = 0.711066, -1.970870, 0.726974
# 8
#  7.  weights = 0.703519, -2.038189, 0.752016
# 8
#  8.  weights = 0.695972, -2.105509, 0.777058
# 8
#  9.  weights = 0.688425, -2.172828, 0.802099
# 7
# 10.  weights = 0.681821, -2.211236, 0.861358
# 7
# 11.  weights = 0.675217, -2.249645, 0.920617
# 7
# 12.  weights = 0.668613, -2.310072, 0.924632
# 6
# 13.  weights = 0.662953, -2.341588, 0.962863
# 6
# 14.  weights = 0.657293, -2.373104, 1.001095
# 6
# 15.  weights = 0.651632, -2.404620, 1.039327
# 6
# 16.  weights = 0.645972, -2.436136, 1.077558
# 6
# 17.  weights = 0.640311, -2.467652, 1.115790
# 6
# 18.  weights = 0.634651, -2.499168, 1.154022
# 6
# 19.  weights = 0.628991, -2.530684, 1.192254
# 5
# 20.  weights = 0.624274, -2.571555, 1.182758
# 5
# 21.  weights = 0.619557, -2.612426, 1.173262
# 5
# 22.  weights = 0.614840, -2.653297, 1.163766
# 5
# 23.  weights = 0.610123, -2.654876, 1.242358
# 4
# 24.  weights = 0.606349, -2.697840, 1.202473
# 3
# 25.  weights = 0.603519, -2.710868, 1.202948
# 3
# 26.  weights = 0.600689, -2.723895, 1.203423
# 3
# 27.  weights = 0.597859, -2.736923, 1.203899
# 3
# 28.  weights = 0.595028, -2.749950, 1.204374
# 3
# 29.  weights = 0.592198, -2.762978, 1.204849
# 3
# 30.  weights = 0.589368, -2.776005, 1.205324
# 3
# 31.  weights = 0.586538, -2.789033, 1.205800
# 3
# 32.  weights = 0.583708, -2.802060, 1.206275
# 3
# 33.  weights = 0.580877, -2.815087, 1.206750
# 3
# 34.  weights = 0.578047, -2.828115, 1.207225
# 3
# 35.  weights = 0.575217, -2.841142, 1.207701
# 3
# 36.  weights = 0.572387, -2.854170, 1.208176
# 3
# 37.  weights = 0.569557, -2.867197, 1.208651
# 3
# 38.  weights = 0.566727, -2.880225, 1.209126
# 3
# 39.  weights = 0.563896, -2.893252, 1.209602
# 3
# 40.  weights = 0.561066, -2.906280, 1.210077
# 3
# 41.  weights = 0.558236, -2.919307, 1.210552
# 3
# 42.  weights = 0.555406, -2.932335, 1.211027
# 3
# 43.  weights = 0.552576, -2.945362, 1.211503
# 3
# 44.  weights = 0.549745, -2.958389, 1.211978
# 3
# 45.  weights = 0.546915, -2.971417, 1.212453
# 3
# 46.  weights = 0.544085, -2.984444, 1.212928
# 3
# 47.  weights = 0.541255, -2.997472, 1.213404
# 3
# 48.  weights = 0.538425, -3.010499, 1.213879
# 3
# 49.  weights = 0.535594, -3.023527, 1.214354
# 2
# 50.  weights = 0.533708, -3.021084, 1.231194
# 3
# 51.  weights = 0.530877, -3.034112, 1.231669
# 2
# 52.  weights = 0.528991, -3.031669, 1.248509
# 2
# 53.  weights = 0.527104, -3.029226, 1.265349
# 3
# 54.  weights = 0.524274, -3.042254, 1.265824
# 2
# 55.  weights = 0.522387, -3.039811, 1.282664
# 3
# 56.  weights = 0.519557, -3.052839, 1.283139
# 2
# 57.  weights = 0.517670, -3.050396, 1.299979
# 2
# 58.  weights = 0.515783, -3.047954, 1.316819
# 3
# 59.  weights = 0.512953, -3.060981, 1.317294
# 2
# 60.  weights = 0.511066, -3.058538, 1.334134
# 3
# 61.  weights = 0.508236, -3.071566, 1.334610
# 2
# 62.  weights = 0.506349, -3.069123, 1.351450
# 2
# 63.  weights = 0.504462, -3.066681, 1.368289
# 3
# 64.  weights = 0.501632, -3.079708, 1.368765
# 2
# 65.  weights = 0.499745, -3.077266, 1.385605
# 3
# 66.  weights = 0.496915, -3.090293, 1.386080
# 2
# 67.  weights = 0.495028, -3.087850, 1.402920
# 2
# 68.  weights = 0.493142, -3.085408, 1.419760
# 3
# 69.  weights = 0.490311, -3.098435, 1.420235
# 2
# 70.  weights = 0.488425, -3.095993, 1.437075
# 3
# 71.  weights = 0.485594, -3.109020, 1.437550
# 2
# 72.  weights = 0.483708, -3.106578, 1.454390
# 2
# 73.  weights = 0.481821, -3.104135, 1.471230
# 3
# 74.  weights = 0.478991, -3.117163, 1.471705
# 2
# 75.  weights = 0.477104, -3.114720, 1.488545
# 3
# 76.  weights = 0.474274, -3.127747, 1.489020
# 2
# 77.  weights = 0.472387, -3.125305, 1.505860
# 2
# 78.  weights = 0.470500, -3.122862, 1.522700
# 3
# 79.  weights = 0.467670, -3.135890, 1.523175
# 2
# 80.  weights = 0.465783, -3.133447, 1.540015
# 3
# 81.  weights = 0.462953, -3.146475, 1.540490
# 2
# 82.  weights = 0.461066, -3.144032, 1.557330
# 2
# 83.  weights = 0.459179, -3.141589, 1.574170
# 3
# 84.  weights = 0.456349, -3.154617, 1.574646
# 2
# 85.  weights = 0.454462, -3.152174, 1.591485
# 3
# 86.  weights = 0.451632, -3.165202, 1.591961
# 2
# 87.  weights = 0.449745, -3.162759, 1.608801
# 2
# 88.  weights = 0.447859, -3.160317, 1.625640
# 3
# 89.  weights = 0.445028, -3.173344, 1.626116
# 2
# 90.  weights = 0.443142, -3.170901, 1.642956
# 2
# 91.  weights = 0.441255, -3.168459, 1.659796
# 3
# 92.  weights = 0.438425, -3.181486, 1.660271
# 2
# 93.  weights = 0.436538, -3.179044, 1.677111
# 3
# 94.  weights = 0.433708, -3.192071, 1.677586
# 2
# 95.  weights = 0.431821, -3.189629, 1.694426
# 2
# 96.  weights = 0.429934, -3.187186, 1.711266
# 3
# 97.  weights = 0.427104, -3.200213, 1.711741
# 2
# 98.  weights = 0.425217, -3.197771, 1.728581
# 3
# 99.  weights = 0.422387, -3.210798, 1.729056

# %% [markdown]
# ### 2-layer XOR problem
#
# In most cases, classification problems are far from being linear. Therefore, we need more advanced methods to be able to compute non-linear class boundaries. The advantage of neural networks is that the same principle can be applied in a *layer-wise* fashion. This allows to further discriminate the space in sub-regions (as seen in the course). We will try to implement the 2-layer *perceptron* that can provide a solution to the infamous XOR problem. The idea is now to have the output of the first neurons to be connected to a set of other neurons. Therefore, if we take back our previous formulation, we have the same output for the first neuron(s) $\hat{y}$, that we will now term as $y^{(1)}$. Then, we feed these outputs to a second layer of neurons, which gives
#
#
# $$
# \begin{equation}
# y^{(2)}=\phi\left(\sum_{i = 1}^{n}w_{i}.y^{(1)}_{i} + b\right)
# %label{eq6}
# \end{equation}
# $$
#
# Finally, we will rely on the same loss $\mathcal{L_{D}}$ as in the previous exercise, but the outputs used are $y_2$ instead of $y$. As in the previous case, we now need to compute the derivatives of the weights and biases for several layers . However, you should see that some form of generalization might be possible for any number of layer.

# %% [markdown]
# ***
#
# **Exercise**
#   1. Perform the derivatives for the last layer specifically
#   2. Define a generalized derivative for any previous layer
#
# ***

# %% [markdown]
# $$
# \frac{\partial L}{\partial w_2} = \frac{\partial L}{\partial y_2} \cdot \frac{\partial y_2}{\partial O_2} \cdot \frac{\partial O_2}{\partial w_2}
# = 2(y_2-y)\phi'(O_2)y_1
# $$
#
# En généralisant à un niveau $n$ et son niveau inférieur $n-1$ :
#
# $$
# \frac{\partial L}{\partial w_n} = \frac{\partial L}{\partial y_n} \cdot \frac{\partial y_n}{\partial O_n} \cdot \frac{\partial O_n}{\partial w_n}
# = 2(y_n-y)\phi'(O_n)y_{n-1}
# $$

# %% [markdown]
# We can construct the prototypical set of XOR values by using the following code (note that this is the most simple case, but still this is typically a problem that cannot be solved by a _linear classifier_

# %%
patterns = np.array([[-1, -1],[-1,  1],[1, -1],[1,  1]]).transpose() # Input patterns



desired = np.array([0, 1, 1, 0])                       # Corresponding classes
# Initialize based on their sizes
nInputs = patterns.shape[0]
nOutputs = 1
nPat = patterns.shape[1]
# First plot the patterns
fig = plot_patterns(patterns, desired);

# %% [markdown]
# The variables that will be used by your code are the following.
#
# ```Matlab
# patterns          % 2 x n matrix of random points
# desired           % classes of the patterns
# inputs1           % 3 x n final matrix of inputs (accounting for bias)
# nHiddens          % Number of hidden units
# learnRate         % Learning rate parameter
# momentum          % Momentum parameter (bonus)
# weights1          % 1st layer weights
# weights2          % 2nd layer weights
# TSS_Limit         % Sum-squared error limit
# ```

# %%
nHiddens = 2           # Number of hidden units
momentum = 0.1         # Momentum parameter
# Overall input patterns
inputs = patterns
TSS_Limit = 0.4                                           # Sum-squared error limit
# Learning rate
eta = 0.005

# %% [markdown]
# ***
#
# **Exercise**
#
#   1. Update the forward propagation and error computation (compared to desired).
#   2. Update the back-propagation part to learn the weights of both layers.
#   3. Run the learning, which should produce a result similar to that displayed below.
#   4. Perform multiple re-runs of the learning procedure (re-launching with different initializations)
#   5. What observations can you make on the learning process?
#   6. What happens if you initialize all weights to zeros?
#   7. (Optional) Implement the *sparsity* constraint in your neural network.
#   7. (Optional) Implement the *weight decay* constraint in your network.
#   7. (Optional) Add the *momentum* to the learning procedure.
#
# *For optional questions, please look after the first code box for more information*
#
# ***

# %%
# Weights of first and second layer
weights1 = (np.random.randn(nHiddens, nInputs) - 0.5)      # 1st layer weights
weights2 = (np.random.randn(nOutputs, nHiddens) - 0.5)     # 2nd layer weights
bias1 = (np.random.randn(nHiddens, 1) - 0.5)               # 1st layer biases
bias2 = (np.random.randn(nOutputs, 1) - 0.5)               # 2nd layer biases
# First plot the patterns
fig = plot_patterns(patterns, desired);
# Iterate for a fixed number of iterations

def sigmoid_activation (x) :
    return 1/(1+np.exp(-x))


for epoch in range(100000):
    #Forward
    y1 = sigmoid_activation(np.matmul(weights1,inputs) + bias1)
    y2 = sigmoid_activation(np.matmul(weights2,y1) + bias2)
  
    #Derivatives
    dphi1 = y1 * (1-y1)
    dphi2 = y2 * (1-y2)
    dw2 = 2 * np.matmul((dphi2 * (y2-desired)),y1.T)
    dw1 = 2 * np.matmul(np.dot(weights2, dphi1 * dphi2 * (y2-desired)),inputs.T)
    
    dbias2 = np.sum(2 * (dphi2 * (y2-desired)))
    dbias1 = np.sum(2 * np.dot(weights2, dphi1 * dphi2 * (y2-desired)))

    #Backward
    weights1 -= eta * dw1
    weights2 -= eta * dw2
    
    bias1 -= eta * dbias1
    bias2 -= eta * dbias2
    
    TSS = np.sum(np.square((desired-y2)))

    print('Epoch %3d:  Error = %f' % (epoch, TSS));
    if TSS < TSS_Limit:
        break
    if (epoch - 1 % 20)==0:
        plot_boundary(np.concatenate((bias2, weights2), axis=1), epoch, '--', fig)

plot_boundary(np.concatenate((bias1, weights1), axis=1), epoch, '-', fig)
# Out:
# Epoch   0:  Error = 1.055082
# Epoch   1:  Error = 1.054765
# Epoch   2:  Error = 1.054450
# Epoch   3:  Error = 1.054137
# Epoch   4:  Error = 1.053827
# Epoch   5:  Error = 1.053518
# Epoch   6:  Error = 1.053211
# Epoch   7:  Error = 1.052907
# Epoch   8:  Error = 1.052605
# Epoch   9:  Error = 1.052304
# Epoch  10:  Error = 1.052006
# Epoch  11:  Error = 1.051709
# Epoch  12:  Error = 1.051415
# Epoch  13:  Error = 1.051123
# Epoch  14:  Error = 1.050832
# Epoch  15:  Error = 1.050544
# Epoch  16:  Error = 1.050257
# Epoch  17:  Error = 1.049973
# Epoch  18:  Error = 1.049690
# Epoch  19:  Error = 1.049409
# Epoch  20:  Error = 1.049130
# Epoch  21:  Error = 1.048854
# Epoch  22:  Error = 1.048579
# Epoch  23:  Error = 1.048305
# Epoch  24:  Error = 1.048034
# Epoch  25:  Error = 1.047765
# Epoch  26:  Error = 1.047497
# Epoch  27:  Error = 1.047231
# Epoch  28:  Error = 1.046967
# Epoch  29:  Error = 1.046705
# Epoch  30:  Error = 1.046445
# Epoch  31:  Error = 1.046186
# Epoch  32:  Error = 1.045929
# Epoch  33:  Error = 1.045674
# Epoch  34:  Error = 1.045421
# Epoch  35:  Error = 1.045169
# Epoch  36:  Error = 1.044919
# Epoch  37:  Error = 1.044671
# Epoch  38:  Error = 1.044424
# Epoch  39:  Error = 1.044180
# Epoch  40:  Error = 1.043937
# Epoch  41:  Error = 1.043695
# Epoch  42:  Error = 1.043455
# Epoch  43:  Error = 1.043217
# Epoch  44:  Error = 1.042981
# Epoch  45:  Error = 1.042746
# Epoch  46:  Error = 1.042513
# Epoch  47:  Error = 1.042281
# Epoch  48:  Error = 1.042051
# Epoch  49:  Error = 1.041823
# Epoch  50:  Error = 1.041596
# Epoch  51:  Error = 1.041370
# Epoch  52:  Error = 1.041147
# Epoch  53:  Error = 1.040925
# Epoch  54:  Error = 1.040704
# Epoch  55:  Error = 1.040485
# Epoch  56:  Error = 1.040267
# Epoch  57:  Error = 1.040051
# Epoch  58:  Error = 1.039836
# Epoch  59:  Error = 1.039623
# Epoch  60:  Error = 1.039412
# Epoch  61:  Error = 1.039202
# Epoch  62:  Error = 1.038993
# Epoch  63:  Error = 1.038786
# Epoch  64:  Error = 1.038580
# Epoch  65:  Error = 1.038375
# Epoch  66:  Error = 1.038172
# Epoch  67:  Error = 1.037971
# Epoch  68:  Error = 1.037771
# Epoch  69:  Error = 1.037572
# Epoch  70:  Error = 1.037374
# Epoch  71:  Error = 1.037178
# Epoch  72:  Error = 1.036984
# Epoch  73:  Error = 1.036790
# Epoch  74:  Error = 1.036598
# Epoch  75:  Error = 1.036408
# Epoch  76:  Error = 1.036218
# Epoch  77:  Error = 1.036030
# Epoch  78:  Error = 1.035844
# Epoch  79:  Error = 1.035658
# Epoch  80:  Error = 1.035474
# Epoch  81:  Error = 1.035291
# Epoch  82:  Error = 1.035110
# Epoch  83:  Error = 1.034930
# Epoch  84:  Error = 1.034751
# Epoch  85:  Error = 1.034573
# Epoch  86:  Error = 1.034396
# Epoch  87:  Error = 1.034221
# Epoch  88:  Error = 1.034047
# Epoch  89:  Error = 1.033874
# Epoch  90:  Error = 1.033702
# Epoch  91:  Error = 1.033532
# Epoch  92:  Error = 1.033363
# Epoch  93:  Error = 1.033194
# Epoch  94:  Error = 1.033028
# Epoch  95:  Error = 1.032862
# Epoch  96:  Error = 1.032697
# Epoch  97:  Error = 1.032534
# Epoch  98:  Error = 1.032371
# Epoch  99:  Error = 1.032210
# Epoch 100:  Error = 1.032050
# Epoch 101:  Error = 1.031891
# Epoch 102:  Error = 1.031733
# Epoch 103:  Error = 1.031576
# Epoch 104:  Error = 1.031421
# Epoch 105:  Error = 1.031266
# Epoch 106:  Error = 1.031113
# Epoch 107:  Error = 1.030960
# Epoch 108:  Error = 1.030809
# Epoch 109:  Error = 1.030658
# Epoch 110:  Error = 1.030509
# Epoch 111:  Error = 1.030361
# Epoch 112:  Error = 1.030214
# Epoch 113:  Error = 1.030067
# Epoch 114:  Error = 1.029922
# Epoch 115:  Error = 1.029778
# Epoch 116:  Error = 1.029635
# Epoch 117:  Error = 1.029493
# Epoch 118:  Error = 1.029352
# Epoch 119:  Error = 1.029211
# Epoch 120:  Error = 1.029072
# Epoch 121:  Error = 1.028934
# Epoch 122:  Error = 1.028796
# Epoch 123:  Error = 1.028660
# Epoch 124:  Error = 1.028525
# Epoch 125:  Error = 1.028390
# Epoch 126:  Error = 1.028257
# Epoch 127:  Error = 1.028124
# Epoch 128:  Error = 1.027992
# Epoch 129:  Error = 1.027862
# Epoch 130:  Error = 1.027732
# Epoch 131:  Error = 1.027603
# Epoch 132:  Error = 1.027475
# Epoch 133:  Error = 1.027347
# Epoch 134:  Error = 1.027221
# Epoch 135:  Error = 1.027095
# Epoch 136:  Error = 1.026971
# Epoch 137:  Error = 1.026847
# Epoch 138:  Error = 1.026724
# Epoch 139:  Error = 1.026602
# Epoch 140:  Error = 1.026481
# Epoch 141:  Error = 1.026361
# Epoch 142:  Error = 1.026241
# Epoch 143:  Error = 1.026122
# Epoch 144:  Error = 1.026004
# Epoch 145:  Error = 1.025887
# Epoch 146:  Error = 1.025771
# Epoch 147:  Error = 1.025656
# Epoch 148:  Error = 1.025541
# Epoch 149:  Error = 1.025427
# Epoch 150:  Error = 1.025314
# Epoch 151:  Error = 1.025201
# Epoch 152:  Error = 1.025090
# Epoch 153:  Error = 1.024979
# Epoch 154:  Error = 1.024869
# Epoch 155:  Error = 1.024760
# Epoch 156:  Error = 1.024651
# Epoch 157:  Error = 1.024543
# Epoch 158:  Error = 1.024436
# Epoch 159:  Error = 1.024330
# Epoch 160:  Error = 1.024224
# Epoch 161:  Error = 1.024119
# Epoch 162:  Error = 1.024015
# Epoch 163:  Error = 1.023911
# Epoch 164:  Error = 1.023809
# Epoch 165:  Error = 1.023706
# Epoch 166:  Error = 1.023605
# Epoch 167:  Error = 1.023504
# Epoch 168:  Error = 1.023404
# Epoch 169:  Error = 1.023305
# Epoch 170:  Error = 1.023206
# Epoch 171:  Error = 1.023108
# Epoch 172:  Error = 1.023011
# Epoch 173:  Error = 1.022914
# Epoch 174:  Error = 1.022818
# Epoch 175:  Error = 1.022723
# Epoch 176:  Error = 1.022628
# Epoch 177:  Error = 1.022534
# Epoch 178:  Error = 1.022440
# Epoch 179:  Error = 1.022347
# Epoch 180:  Error = 1.022255
# Epoch 181:  Error = 1.022163
# Epoch 182:  Error = 1.022072
# Epoch 183:  Error = 1.021982
# Epoch 184:  Error = 1.021892
# Epoch 185:  Error = 1.021803
# Epoch 186:  Error = 1.021714
# Epoch 187:  Error = 1.021626
# Epoch 188:  Error = 1.021539
# Epoch 189:  Error = 1.021452
# Epoch 190:  Error = 1.021366
# Epoch 191:  Error = 1.021280
# Epoch 192:  Error = 1.021195
# Epoch 193:  Error = 1.021110
# Epoch 194:  Error = 1.021026
# Epoch 195:  Error = 1.020943
# Epoch 196:  Error = 1.020860
# Epoch 197:  Error = 1.020777
# Epoch 198:  Error = 1.020695
# Epoch 199:  Error = 1.020614
# Epoch 200:  Error = 1.020533
# Epoch 201:  Error = 1.020453
# Epoch 202:  Error = 1.020373
# Epoch 203:  Error = 1.020294
# Epoch 204:  Error = 1.020216
# Epoch 205:  Error = 1.020137
# Epoch 206:  Error = 1.020060
# Epoch 207:  Error = 1.019983
# Epoch 208:  Error = 1.019906
# Epoch 209:  Error = 1.019830
# Epoch 210:  Error = 1.019754
# Epoch 211:  Error = 1.019679
# Epoch 212:  Error = 1.019604
# Epoch 213:  Error = 1.019530
# Epoch 214:  Error = 1.019456
# Epoch 215:  Error = 1.019383
# Epoch 216:  Error = 1.019310
# Epoch 217:  Error = 1.019238
# Epoch 218:  Error = 1.019166
# Epoch 219:  Error = 1.019095
# Epoch 220:  Error = 1.019024
# Epoch 221:  Error = 1.018954
# Epoch 222:  Error = 1.018884
# Epoch 223:  Error = 1.018814
# Epoch 224:  Error = 1.018745
# Epoch 225:  Error = 1.018676
# Epoch 226:  Error = 1.018608
# Epoch 227:  Error = 1.018540
# Epoch 228:  Error = 1.018473
# Epoch 229:  Error = 1.018406
# Epoch 230:  Error = 1.018339
# Epoch 231:  Error = 1.018273
# Epoch 232:  Error = 1.018208
# Epoch 233:  Error = 1.018142
# Epoch 234:  Error = 1.018077
# Epoch 235:  Error = 1.018013
# Epoch 236:  Error = 1.017949
# Epoch 237:  Error = 1.017885
# Epoch 238:  Error = 1.017822
# Epoch 239:  Error = 1.017759
# Epoch 240:  Error = 1.017697
# Epoch 241:  Error = 1.017635
# Epoch 242:  Error = 1.017573
# Epoch 243:  Error = 1.017512
# Epoch 244:  Error = 1.017451
# Epoch 245:  Error = 1.017390
# Epoch 246:  Error = 1.017330
# Epoch 247:  Error = 1.017270
# Epoch 248:  Error = 1.017211
# Epoch 249:  Error = 1.017152
# Epoch 250:  Error = 1.017093
# Epoch 251:  Error = 1.017035
# Epoch 252:  Error = 1.016977
# Epoch 253:  Error = 1.016919
# Epoch 254:  Error = 1.016862
# Epoch 255:  Error = 1.016805
# Epoch 256:  Error = 1.016748
# Epoch 257:  Error = 1.016692
# Epoch 258:  Error = 1.016636
# Epoch 259:  Error = 1.016580
# Epoch 260:  Error = 1.016525
# Epoch 261:  Error = 1.016470
# Epoch 262:  Error = 1.016415
# Epoch 263:  Error = 1.016361
# Epoch 264:  Error = 1.016307
# Epoch 265:  Error = 1.016254
# Epoch 266:  Error = 1.016200
# Epoch 267:  Error = 1.016147
# Epoch 268:  Error = 1.016095
# Epoch 269:  Error = 1.016042
# Epoch 270:  Error = 1.015990
# Epoch 271:  Error = 1.015939
# Epoch 272:  Error = 1.015887
# Epoch 273:  Error = 1.015836
# Epoch 274:  Error = 1.015785
# Epoch 275:  Error = 1.015735
# Epoch 276:  Error = 1.015684
# Epoch 277:  Error = 1.015634
# Epoch 278:  Error = 1.015585
# Epoch 279:  Error = 1.015535
# Epoch 280:  Error = 1.015486
# Epoch 281:  Error = 1.015437
# Epoch 282:  Error = 1.015389
# Epoch 283:  Error = 1.015341
# Epoch 284:  Error = 1.015293
# Epoch 285:  Error = 1.015245
# Epoch 286:  Error = 1.015198
# Epoch 287:  Error = 1.015150
# Epoch 288:  Error = 1.015104
# Epoch 289:  Error = 1.015057
# Epoch 290:  Error = 1.015011
# Epoch 291:  Error = 1.014965
# Epoch 292:  Error = 1.014919
# Epoch 293:  Error = 1.014873
# Epoch 294:  Error = 1.014828
# Epoch 295:  Error = 1.014783
# Epoch 296:  Error = 1.014738
# Epoch 297:  Error = 1.014693
# Epoch 298:  Error = 1.014649
# Epoch 299:  Error = 1.014605
# Epoch 300:  Error = 1.014561
# Epoch 301:  Error = 1.014518
# Epoch 302:  Error = 1.014474
# Epoch 303:  Error = 1.014431
# Epoch 304:  Error = 1.014388
# Epoch 305:  Error = 1.014346
# Epoch 306:  Error = 1.014303
# Epoch 307:  Error = 1.014261
# Epoch 308:  Error = 1.014219
# Epoch 309:  Error = 1.014177
# Epoch 310:  Error = 1.014136
# Epoch 311:  Error = 1.014095
# Epoch 312:  Error = 1.014054
# Epoch 313:  Error = 1.014013
# Epoch 314:  Error = 1.013972
# Epoch 315:  Error = 1.013932
# Epoch 316:  Error = 1.013892
# Epoch 317:  Error = 1.013852
# Epoch 318:  Error = 1.013812
# Epoch 319:  Error = 1.013772
# Epoch 320:  Error = 1.013733
# Epoch 321:  Error = 1.013694
# Epoch 322:  Error = 1.013655
# Epoch 323:  Error = 1.013616
# Epoch 324:  Error = 1.013578
# Epoch 325:  Error = 1.013539
# Epoch 326:  Error = 1.013501
# Epoch 327:  Error = 1.013463
# Epoch 328:  Error = 1.013426
# Epoch 329:  Error = 1.013388
# Epoch 330:  Error = 1.013351
# Epoch 331:  Error = 1.013313
# Epoch 332:  Error = 1.013277
# Epoch 333:  Error = 1.013240
# Epoch 334:  Error = 1.013203
# Epoch 335:  Error = 1.013167
# Epoch 336:  Error = 1.013131
# Epoch 337:  Error = 1.013094
# Epoch 338:  Error = 1.013059
# Epoch 339:  Error = 1.013023
# Epoch 340:  Error = 1.012987
# Epoch 341:  Error = 1.012952
# Epoch 342:  Error = 1.012917
# Epoch 343:  Error = 1.012882
# Epoch 344:  Error = 1.012847
# Epoch 345:  Error = 1.012812
# Epoch 346:  Error = 1.012778
# Epoch 347:  Error = 1.012744
# Epoch 348:  Error = 1.012710
# Epoch 349:  Error = 1.012676
# Epoch 350:  Error = 1.012642
# Epoch 351:  Error = 1.012608
# Epoch 352:  Error = 1.012575
# Epoch 353:  Error = 1.012541
# Epoch 354:  Error = 1.012508
# Epoch 355:  Error = 1.012475
# Epoch 356:  Error = 1.012442
# Epoch 357:  Error = 1.012410
# Epoch 358:  Error = 1.012377
# Epoch 359:  Error = 1.012345
# Epoch 360:  Error = 1.012312
# Epoch 361:  Error = 1.012280
# Epoch 362:  Error = 1.012248
# Epoch 363:  Error = 1.012217
# Epoch 364:  Error = 1.012185
# Epoch 365:  Error = 1.012153
# Epoch 366:  Error = 1.012122
# Epoch 367:  Error = 1.012091
# Epoch 368:  Error = 1.012060
# Epoch 369:  Error = 1.012029
# Epoch 370:  Error = 1.011998
# Epoch 371:  Error = 1.011967
# Epoch 372:  Error = 1.011937
# Epoch 373:  Error = 1.011906
# Epoch 374:  Error = 1.011876
# Epoch 375:  Error = 1.011846
# Epoch 376:  Error = 1.011816
# Epoch 377:  Error = 1.011786
# Epoch 378:  Error = 1.011757
# Epoch 379:  Error = 1.011727
# Epoch 380:  Error = 1.011697
# Epoch 381:  Error = 1.011668
# Epoch 382:  Error = 1.011639
# Epoch 383:  Error = 1.011610
# Epoch 384:  Error = 1.011581
# Epoch 385:  Error = 1.011552
# Epoch 386:  Error = 1.011523
# Epoch 387:  Error = 1.011495
# Epoch 388:  Error = 1.011466
# Epoch 389:  Error = 1.011438
# Epoch 390:  Error = 1.011410
# Epoch 391:  Error = 1.011382
# Epoch 392:  Error = 1.011354
# Epoch 393:  Error = 1.011326
# Epoch 394:  Error = 1.011298
# Epoch 395:  Error = 1.011270
# Epoch 396:  Error = 1.011243
# Epoch 397:  Error = 1.011215
# Epoch 398:  Error = 1.011188
# Epoch 399:  Error = 1.011161
# Epoch 400:  Error = 1.011134
# Epoch 401:  Error = 1.011107
# Epoch 402:  Error = 1.011080
# Epoch 403:  Error = 1.011053
# Epoch 404:  Error = 1.011027
# Epoch 405:  Error = 1.011000
# Epoch 492:  Error = 1.009013
# Epoch 493:  Error = 1.008994
# Epoch 494:  Error = 1.008974
# Epoch 495:  Error = 1.008954
# Epoch 496:  Error = 1.008934
# Epoch 497:  Error = 1.008915
# Epoch 498:  Error = 1.008895
# Epoch 499:  Error = 1.008875
# Epoch 500:  Error = 1.008856
# Epoch 501:  Error = 1.008836
# Epoch 502:  Error = 1.008817
# Epoch 503:  Error = 1.008797
# Epoch 504:  Error = 1.008778
# Epoch 505:  Error = 1.008759
# Epoch 506:  Error = 1.008740
# Epoch 507:  Error = 1.008720
# Epoch 508:  Error = 1.008701
# Epoch 509:  Error = 1.008682
# Epoch 510:  Error = 1.008663
# Epoch 511:  Error = 1.008644
# Epoch 512:  Error = 1.008625
# Epoch 513:  Error = 1.008606
# Epoch 514:  Error = 1.008587
# Epoch 515:  Error = 1.008568
# Epoch 516:  Error = 1.008550
# Epoch 517:  Error = 1.008531
# Epoch 518:  Error = 1.008512
# Epoch 519:  Error = 1.008494
# Epoch 520:  Error = 1.008475
# Epoch 521:  Error = 1.008456
# Epoch 522:  Error = 1.008438
# Epoch 523:  Error = 1.008419
# Epoch 524:  Error = 1.008401
# Epoch 525:  Error = 1.008382
# Epoch 526:  Error = 1.008364
# Epoch 527:  Error = 1.008346
# Epoch 528:  Error = 1.008327
# Epoch 529:  Error = 1.008309
# Epoch 530:  Error = 1.008291
# Epoch 531:  Error = 1.008273
# Epoch 532:  Error = 1.008255
# Epoch 533:  Error = 1.008237
# Epoch 534:  Error = 1.008219
# Epoch 535:  Error = 1.008201
# Epoch 536:  Error = 1.008183
# Epoch 537:  Error = 1.008165
# Epoch 538:  Error = 1.008147
# Epoch 539:  Error = 1.008129
# Epoch 540:  Error = 1.008111
# Epoch 541:  Error = 1.008093
# Epoch 542:  Error = 1.008075
# Epoch 543:  Error = 1.008058
# Epoch 544:  Error = 1.008040
# Epoch 545:  Error = 1.008022
# Epoch 546:  Error = 1.008005
# Epoch 547:  Error = 1.007987
# Epoch 548:  Error = 1.007970
# Epoch 549:  Error = 1.007952
# Epoch 550:  Error = 1.007935
# Epoch 551:  Error = 1.007917
# Epoch 552:  Error = 1.007900
# Epoch 553:  Error = 1.007882
# Epoch 554:  Error = 1.007865
# Epoch 555:  Error = 1.007848
# Epoch 556:  Error = 1.007830
# Epoch 557:  Error = 1.007813
# Epoch 558:  Error = 1.007796
# Epoch 559:  Error = 1.007779
# Epoch 560:  Error = 1.007762
# Epoch 561:  Error = 1.007744
# Epoch 562:  Error = 1.007727
# Epoch 563:  Error = 1.007710
# Epoch 564:  Error = 1.007693
# Epoch 565:  Error = 1.007676
# Epoch 566:  Error = 1.007659
# Epoch 567:  Error = 1.007642
# Epoch 568:  Error = 1.007625
# Epoch 569:  Error = 1.007608
# Epoch 570:  Error = 1.007592
# Epoch 571:  Error = 1.007575
# Epoch 572:  Error = 1.007558
# Epoch 573:  Error = 1.007541
# Epoch 574:  Error = 1.007524
# Epoch 575:  Error = 1.007508
# Epoch 576:  Error = 1.007491
# Epoch 577:  Error = 1.007474
# Epoch 578:  Error = 1.007458
# Epoch 579:  Error = 1.007441
# Epoch 580:  Error = 1.007425
# Epoch 581:  Error = 1.007408
# Epoch 582:  Error = 1.007391
# Epoch 583:  Error = 1.007375
# Epoch 584:  Error = 1.007358
# Epoch 585:  Error = 1.007342
# Epoch 586:  Error = 1.007326
# Epoch 587:  Error = 1.007309
# Epoch 588:  Error = 1.007293
# Epoch 589:  Error = 1.007276
# Epoch 590:  Error = 1.007260
# Epoch 591:  Error = 1.007244
# Epoch 592:  Error = 1.007228
# Epoch 593:  Error = 1.007211
# Epoch 594:  Error = 1.007195
# Epoch 595:  Error = 1.007179
# Epoch 596:  Error = 1.007163
# Epoch 597:  Error = 1.007146
# Epoch 598:  Error = 1.007130
# Epoch 599:  Error = 1.007114
# Epoch 600:  Error = 1.007098
# Epoch 601:  Error = 1.007082
# Epoch 602:  Error = 1.007066
# Epoch 603:  Error = 1.007050
# Epoch 604:  Error = 1.007034
# Epoch 605:  Error = 1.007018
# Epoch 606:  Error = 1.007002
# Epoch 607:  Error = 1.006986
# Epoch 608:  Error = 1.006970
# Epoch 609:  Error = 1.006954
# Epoch 610:  Error = 1.006938
# Epoch 611:  Error = 1.006923
# Epoch 612:  Error = 1.006907
# Epoch 613:  Error = 1.006891
# Epoch 614:  Error = 1.006875
# Epoch 615:  Error = 1.006859
# Epoch 616:  Error = 1.006844
# Epoch 617:  Error = 1.006828
# Epoch 618:  Error = 1.006812
# Epoch 619:  Error = 1.006797
# Epoch 620:  Error = 1.006781
# Epoch 621:  Error = 1.006765
# Epoch 622:  Error = 1.006750
# Epoch 623:  Error = 1.006734
# Epoch 624:  Error = 1.006718
# Epoch 625:  Error = 1.006703
# Epoch 626:  Error = 1.006687
# Epoch 627:  Error = 1.006672
# Epoch 628:  Error = 1.006656
# Epoch 629:  Error = 1.006641
# Epoch 630:  Error = 1.006625
# Epoch 631:  Error = 1.006610
# Epoch 632:  Error = 1.006594
# Epoch 633:  Error = 1.006579
# Epoch 634:  Error = 1.006564
# Epoch 635:  Error = 1.006548
# Epoch 636:  Error = 1.006533
# Epoch 637:  Error = 1.006517
# Epoch 638:  Error = 1.006502
# Epoch 639:  Error = 1.006487
# Epoch 640:  Error = 1.006471
# Epoch 641:  Error = 1.006456
# Epoch 642:  Error = 1.006441
# Epoch 643:  Error = 1.006426
# Epoch 644:  Error = 1.006410
# Epoch 645:  Error = 1.006395
# Epoch 646:  Error = 1.006380
# Epoch 647:  Error = 1.006365
# Epoch 648:  Error = 1.006350
# Epoch 649:  Error = 1.006334
# Epoch 650:  Error = 1.006319
# Epoch 651:  Error = 1.006304
# Epoch 652:  Error = 1.006289
# Epoch 653:  Error = 1.006274
# Epoch 654:  Error = 1.006259
# Epoch 655:  Error = 1.006244
# Epoch 656:  Error = 1.006229
# Epoch 657:  Error = 1.006214
# Epoch 658:  Error = 1.006199
# Epoch 659:  Error = 1.006184
# Epoch 660:  Error = 1.006169
# Epoch 661:  Error = 1.006154
# Epoch 662:  Error = 1.006139
# Epoch 663:  Error = 1.006124
# Epoch 664:  Error = 1.006109
# Epoch 665:  Error = 1.006094
# Epoch 666:  Error = 1.006079
# Epoch 667:  Error = 1.006064
# Epoch 668:  Error = 1.006049
# Epoch 669:  Error = 1.006034
# Epoch 670:  Error = 1.006020
# Epoch 671:  Error = 1.006005
# Epoch 672:  Error = 1.005990
# Epoch 673:  Error = 1.005975
# Epoch 674:  Error = 1.005960
# Epoch 675:  Error = 1.005946
# Epoch 676:  Error = 1.005931
# Epoch 677:  Error = 1.005916
# Epoch 678:  Error = 1.005901
# Epoch 679:  Error = 1.005887
# Epoch 680:  Error = 1.005872
# Epoch 681:  Error = 1.005857
# Epoch 682:  Error = 1.005842
# Epoch 683:  Error = 1.005828
# Epoch 684:  Error = 1.005813
# Epoch 685:  Error = 1.005798
# Epoch 686:  Error = 1.005784
# Epoch 687:  Error = 1.005769
# Epoch 688:  Error = 1.005755
# Epoch 689:  Error = 1.005740
# Epoch 690:  Error = 1.005725
# Epoch 691:  Error = 1.005711
# Epoch 692:  Error = 1.005696
# Epoch 693:  Error = 1.005682
# Epoch 694:  Error = 1.005667
# Epoch 695:  Error = 1.005652
# Epoch 696:  Error = 1.005638
# Epoch 697:  Error = 1.005623
# Epoch 698:  Error = 1.005609
# Epoch 699:  Error = 1.005594
# Epoch 700:  Error = 1.005580
# Epoch 701:  Error = 1.005565
# Epoch 702:  Error = 1.005551
# Epoch 703:  Error = 1.005537
# Epoch 704:  Error = 1.005522
# Epoch 705:  Error = 1.005508
# Epoch 706:  Error = 1.005493
# Epoch 707:  Error = 1.005479
# Epoch 708:  Error = 1.005464
# Epoch 709:  Error = 1.005450
# Epoch 710:  Error = 1.005436
# Epoch 711:  Error = 1.005421
# Epoch 712:  Error = 1.005407
# Epoch 713:  Error = 1.005393
# Epoch 714:  Error = 1.005378
# Epoch 715:  Error = 1.005364
# Epoch 716:  Error = 1.005350
# Epoch 717:  Error = 1.005335
# Epoch 718:  Error = 1.005321
# Epoch 719:  Error = 1.005307
# Epoch 720:  Error = 1.005292
# Epoch 721:  Error = 1.005278
# Epoch 722:  Error = 1.005264
# Epoch 723:  Error = 1.005250
# Epoch 724:  Error = 1.005235
# Epoch 725:  Error = 1.005221
# Epoch 726:  Error = 1.005207
# Epoch 727:  Error = 1.005193
# Epoch 728:  Error = 1.005178
# Epoch 729:  Error = 1.005164
# Epoch 730:  Error = 1.005150
# Epoch 731:  Error = 1.005136
# Epoch 732:  Error = 1.005122
# Epoch 733:  Error = 1.005107
# Epoch 734:  Error = 1.005093
# Epoch 735:  Error = 1.005079
# Epoch 736:  Error = 1.005065
# Epoch 737:  Error = 1.005051
# Epoch 738:  Error = 1.005037
# Epoch 739:  Error = 1.005023
# Epoch 740:  Error = 1.005008
# Epoch 741:  Error = 1.004994
# Epoch 742:  Error = 1.004980
# Epoch 743:  Error = 1.004966
# Epoch 744:  Error = 1.004952
# Epoch 745:  Error = 1.004938
# Epoch 746:  Error = 1.004924
# Epoch 747:  Error = 1.004910
# Epoch 748:  Error = 1.004896
# Epoch 749:  Error = 1.004882
# Epoch 750:  Error = 1.004868
# Epoch 751:  Error = 1.004854
# Epoch 752:  Error = 1.004840
# Epoch 753:  Error = 1.004826
# Epoch 754:  Error = 1.004812
# Epoch 755:  Error = 1.004798
# Epoch 756:  Error = 1.004784
# Epoch 757:  Error = 1.004770
# Epoch 758:  Error = 1.004756
# Epoch 759:  Error = 1.004742
# Epoch 760:  Error = 1.004728
# Epoch 761:  Error = 1.004714
# Epoch 762:  Error = 1.004700
# Epoch 763:  Error = 1.004686
# Epoch 764:  Error = 1.004672
# Epoch 765:  Error = 1.004658
# Epoch 766:  Error = 1.004644
# Epoch 767:  Error = 1.004630
# Epoch 768:  Error = 1.004616
# Epoch 769:  Error = 1.004602
# Epoch 770:  Error = 1.004589
# Epoch 771:  Error = 1.004575
# Epoch 772:  Error = 1.004561
# Epoch 773:  Error = 1.004547
# Epoch 774:  Error = 1.004533
# Epoch 775:  Error = 1.004519
# Epoch 776:  Error = 1.004505
# Epoch 777:  Error = 1.004491
# Epoch 778:  Error = 1.004478
# Epoch 779:  Error = 1.004464
# Epoch 780:  Error = 1.004450
# Epoch 781:  Error = 1.004436
# Epoch 782:  Error = 1.004422
# Epoch 783:  Error = 1.004408
# Epoch 784:  Error = 1.004395
# Epoch 785:  Error = 1.004381
# Epoch 786:  Error = 1.004367
# Epoch 787:  Error = 1.004353
# Epoch 788:  Error = 1.004339
# Epoch 789:  Error = 1.004326
# Epoch 790:  Error = 1.004312
# Epoch 791:  Error = 1.004298
# Epoch 792:  Error = 1.004284
# Epoch 793:  Error = 1.004271
# Epoch 794:  Error = 1.004257
# Epoch 795:  Error = 1.004243
# Epoch 796:  Error = 1.004229
# Epoch 797:  Error = 1.004216
# Epoch 798:  Error = 1.004202
# Epoch 799:  Error = 1.004188
# Epoch 800:  Error = 1.004174
# Epoch 801:  Error = 1.004161
# Epoch 802:  Error = 1.004147
# Epoch 803:  Error = 1.004133
# Epoch 804:  Error = 1.004120
# Epoch 805:  Error = 1.004106
# Epoch 806:  Error = 1.004092
# Epoch 807:  Error = 1.004078
# Epoch 808:  Error = 1.004065
# Epoch 809:  Error = 1.004051
# Epoch 810:  Error = 1.004037
# Epoch 811:  Error = 1.004024
# Epoch 812:  Error = 1.004010
# Epoch 813:  Error = 1.003996
# Epoch 814:  Error = 1.003983
# Epoch 815:  Error = 1.003969
# Epoch 816:  Error = 1.003955
# Epoch 817:  Error = 1.003942
# Epoch 818:  Error = 1.003928
# Epoch 819:  Error = 1.003914
# Epoch 820:  Error = 1.003901
# Epoch 821:  Error = 1.003887
# Epoch 822:  Error = 1.003874
# Epoch 823:  Error = 1.003860
# Epoch 824:  Error = 1.003846
# Epoch 825:  Error = 1.003833
# Epoch 826:  Error = 1.003819
# Epoch 827:  Error = 1.003806
# Epoch 828:  Error = 1.003792
# Epoch 829:  Error = 1.003778
# Epoch 830:  Error = 1.003765
# Epoch 831:  Error = 1.003751
# Epoch 832:  Error = 1.003738
# Epoch 833:  Error = 1.003724
# Epoch 834:  Error = 1.003710
# Epoch 835:  Error = 1.003697
# Epoch 836:  Error = 1.003683
# Epoch 837:  Error = 1.003670
# Epoch 838:  Error = 1.003656
# Epoch 839:  Error = 1.003643
# Epoch 840:  Error = 1.003629
# Epoch 841:  Error = 1.003616
# Epoch 842:  Error = 1.003602
# Epoch 843:  Error = 1.003588
# Epoch 844:  Error = 1.003575
# Epoch 845:  Error = 1.003561
# Epoch 846:  Error = 1.003548
# Epoch 847:  Error = 1.003534
# Epoch 848:  Error = 1.003521
# Epoch 849:  Error = 1.003507
# Epoch 850:  Error = 1.003494
# Epoch 851:  Error = 1.003480
# Epoch 852:  Error = 1.003467
# Epoch 853:  Error = 1.003453
# Epoch 854:  Error = 1.003440
# Epoch 855:  Error = 1.003426
# Epoch 856:  Error = 1.003413
# Epoch 857:  Error = 1.003399
# Epoch 858:  Error = 1.003386
# Epoch 859:  Error = 1.003372
# Epoch 860:  Error = 1.003359
# Epoch 861:  Error = 1.003345
# Epoch 862:  Error = 1.003332
# Epoch 863:  Error = 1.003318
# Epoch 864:  Error = 1.003305
# Epoch 865:  Error = 1.003291
# Epoch 866:  Error = 1.003278
# Epoch 867:  Error = 1.003265
# Epoch 868:  Error = 1.003251
# Epoch 869:  Error = 1.003238
# Epoch 870:  Error = 1.003224
# Epoch 871:  Error = 1.003211
# Epoch 872:  Error = 1.003197
# Epoch 873:  Error = 1.003184
# Epoch 874:  Error = 1.003170
# Epoch 875:  Error = 1.003157
# Epoch 876:  Error = 1.003144
# Epoch 877:  Error = 1.003130
# Epoch 878:  Error = 1.003117
# Epoch 879:  Error = 1.003103
# Epoch 880:  Error = 1.003090
# Epoch 881:  Error = 1.003076
# Epoch 882:  Error = 1.003063
# Epoch 883:  Error = 1.003050
# Epoch 884:  Error = 1.003036
# Epoch 885:  Error = 1.003023
# Epoch 886:  Error = 1.003009
# Epoch 887:  Error = 1.002996
# Epoch 888:  Error = 1.002983
# Epoch 889:  Error = 1.002969
# Epoch 890:  Error = 1.002956
# Epoch 891:  Error = 1.002942
# Epoch 892:  Error = 1.002929
# Epoch 893:  Error = 1.002916
# Epoch 894:  Error = 1.002902
# Epoch 895:  Error = 1.002889
# Epoch 896:  Error = 1.002875
# Epoch 897:  Error = 1.002862
# Epoch 898:  Error = 1.002849
# Epoch 899:  Error = 1.002835
# Epoch 900:  Error = 1.002822
# Epoch 901:  Error = 1.002809
# Epoch 902:  Error = 1.002795
# Epoch 903:  Error = 1.002782
# Epoch 904:  Error = 1.002768
# Epoch 905:  Error = 1.002755
# Epoch 906:  Error = 1.002742
# Epoch 907:  Error = 1.002728
# Epoch 908:  Error = 1.002715
# Epoch 909:  Error = 1.002702
# Epoch 910:  Error = 1.002688
# Epoch 911:  Error = 1.002675
# Epoch 912:  Error = 1.002662
# Epoch 913:  Error = 1.002648
# Epoch 914:  Error = 1.002635
# Epoch 915:  Error = 1.002622
# Epoch 916:  Error = 1.002608
# Epoch 917:  Error = 1.002595
# Epoch 918:  Error = 1.002582
# Epoch 919:  Error = 1.002568
# Epoch 920:  Error = 1.002555
# Epoch 14546:  Error = 0.410269
# Epoch 14547:  Error = 0.410248
# Epoch 14548:  Error = 0.410226
# Epoch 14549:  Error = 0.410205
# Epoch 14550:  Error = 0.410183
# Epoch 14551:  Error = 0.410161
# Epoch 14552:  Error = 0.410140
# Epoch 14553:  Error = 0.410118
# Epoch 14554:  Error = 0.410097
# Epoch 14555:  Error = 0.410075
# Epoch 14556:  Error = 0.410054
# Epoch 14557:  Error = 0.410032
# Epoch 14558:  Error = 0.410010
# Epoch 14559:  Error = 0.409989
# Epoch 14560:  Error = 0.409967
# Epoch 14561:  Error = 0.409946
# Epoch 14562:  Error = 0.409924
# Epoch 14563:  Error = 0.409903
# Epoch 14564:  Error = 0.409881
# Epoch 14565:  Error = 0.409859
# Epoch 14566:  Error = 0.409838
# Epoch 14567:  Error = 0.409816
# Epoch 14568:  Error = 0.409795
# Epoch 14569:  Error = 0.409773
# Epoch 14570:  Error = 0.409752
# Epoch 14571:  Error = 0.409730
# Epoch 14572:  Error = 0.409709
# Epoch 14573:  Error = 0.409687
# Epoch 14574:  Error = 0.409666
# Epoch 14575:  Error = 0.409644
# Epoch 14576:  Error = 0.409623
# Epoch 14577:  Error = 0.409601
# Epoch 14578:  Error = 0.409580
# Epoch 14579:  Error = 0.409558
# Epoch 14580:  Error = 0.409537
# Epoch 14581:  Error = 0.409515
# Epoch 14582:  Error = 0.409494
# Epoch 14583:  Error = 0.409472
# Epoch 14584:  Error = 0.409451
# Epoch 14585:  Error = 0.409429
# Epoch 14586:  Error = 0.409408
# Epoch 14587:  Error = 0.409386
# Epoch 14588:  Error = 0.409365
# Epoch 14589:  Error = 0.409343
# Epoch 14590:  Error = 0.409322
# Epoch 14591:  Error = 0.409300
# Epoch 14592:  Error = 0.409279
# Epoch 14593:  Error = 0.409257
# Epoch 14594:  Error = 0.409236
# Epoch 14595:  Error = 0.409214
# Epoch 14596:  Error = 0.409193
# Epoch 14597:  Error = 0.409171
# Epoch 14598:  Error = 0.409150
# Epoch 14599:  Error = 0.409128
# Epoch 14600:  Error = 0.409107
# Epoch 14601:  Error = 0.409085
# Epoch 14602:  Error = 0.409064
# Epoch 14603:  Error = 0.409043
# Epoch 14604:  Error = 0.409021
# Epoch 14605:  Error = 0.409000
# Epoch 14606:  Error = 0.408978
# Epoch 14607:  Error = 0.408957
# Epoch 14608:  Error = 0.408935
# Epoch 14609:  Error = 0.408914
# Epoch 14610:  Error = 0.408892
# Epoch 14611:  Error = 0.408871
# Epoch 14612:  Error = 0.408850
# Epoch 14613:  Error = 0.408828
# Epoch 14614:  Error = 0.408807
# Epoch 14615:  Error = 0.408785
# Epoch 14616:  Error = 0.408764
# Epoch 14617:  Error = 0.408743
# Epoch 14618:  Error = 0.408721
# Epoch 14619:  Error = 0.408700
# Epoch 14620:  Error = 0.408678
# Epoch 14621:  Error = 0.408657
# Epoch 14622:  Error = 0.408635
# Epoch 14623:  Error = 0.408614
# Epoch 14624:  Error = 0.408593
# Epoch 14625:  Error = 0.408571
# Epoch 14626:  Error = 0.408550
# Epoch 14627:  Error = 0.408529
# Epoch 14628:  Error = 0.408507
# Epoch 14629:  Error = 0.408486
# Epoch 14630:  Error = 0.408464
# Epoch 14631:  Error = 0.408443
# Epoch 14632:  Error = 0.408422
# Epoch 14633:  Error = 0.408400
# Epoch 14634:  Error = 0.408379
# Epoch 14635:  Error = 0.408358
# Epoch 14636:  Error = 0.408336
# Epoch 14637:  Error = 0.408315
# Epoch 14638:  Error = 0.408293
# Epoch 14639:  Error = 0.408272
# Epoch 14640:  Error = 0.408251
# Epoch 14641:  Error = 0.408229
# Epoch 14642:  Error = 0.408208
# Epoch 14643:  Error = 0.408187
# Epoch 14644:  Error = 0.408165
# Epoch 14645:  Error = 0.408144
# Epoch 14646:  Error = 0.408123
# Epoch 14647:  Error = 0.408101
# Epoch 14648:  Error = 0.408080
# Epoch 14649:  Error = 0.408059
# Epoch 14650:  Error = 0.408037
# Epoch 14651:  Error = 0.408016
# Epoch 14652:  Error = 0.407995
# Epoch 14653:  Error = 0.407973
# Epoch 14654:  Error = 0.407952
# Epoch 14655:  Error = 0.407931
# Epoch 14656:  Error = 0.407909
# Epoch 14657:  Error = 0.407888
# Epoch 14658:  Error = 0.407867
# Epoch 14659:  Error = 0.407845
# Epoch 14660:  Error = 0.407824
# Epoch 14661:  Error = 0.407803
# Epoch 14662:  Error = 0.407782
# Epoch 14663:  Error = 0.407760
# Epoch 14664:  Error = 0.407739
# Epoch 14665:  Error = 0.407718
# Epoch 14666:  Error = 0.407696
# Epoch 14667:  Error = 0.407675
# Epoch 14668:  Error = 0.407654
# Epoch 14669:  Error = 0.407633
# Epoch 14670:  Error = 0.407611
# Epoch 14671:  Error = 0.407590
# Epoch 14672:  Error = 0.407569
# Epoch 14673:  Error = 0.407547
# Epoch 14674:  Error = 0.407526
# Epoch 14675:  Error = 0.407505
# Epoch 14676:  Error = 0.407484
# Epoch 14677:  Error = 0.407462
# Epoch 14678:  Error = 0.407441
# Epoch 14679:  Error = 0.407420
# Epoch 14680:  Error = 0.407399
# Epoch 14681:  Error = 0.407377
# Epoch 14682:  Error = 0.407356
# Epoch 14683:  Error = 0.407335
# Epoch 14684:  Error = 0.407314
# Epoch 14685:  Error = 0.407292
# Epoch 14686:  Error = 0.407271
# Epoch 14687:  Error = 0.407250
# Epoch 14688:  Error = 0.407229
# Epoch 14689:  Error = 0.407208
# Epoch 14690:  Error = 0.407186
# Epoch 14691:  Error = 0.407165
# Epoch 14692:  Error = 0.407144
# Epoch 14693:  Error = 0.407123
# Epoch 14694:  Error = 0.407101
# Epoch 14695:  Error = 0.407080
# Epoch 14696:  Error = 0.407059
# Epoch 14697:  Error = 0.407038
# Epoch 14698:  Error = 0.407017
# Epoch 14699:  Error = 0.406995
# Epoch 14700:  Error = 0.406974
# Epoch 14701:  Error = 0.406953
# Epoch 14702:  Error = 0.406932
# Epoch 14703:  Error = 0.406911
# Epoch 14704:  Error = 0.406889
# Epoch 14705:  Error = 0.406868
# Epoch 14706:  Error = 0.406847
# Epoch 14707:  Error = 0.406826
# Epoch 14708:  Error = 0.406805
# Epoch 14709:  Error = 0.406784
# Epoch 14710:  Error = 0.406762
# Epoch 14711:  Error = 0.406741
# Epoch 14712:  Error = 0.406720
# Epoch 14713:  Error = 0.406699
# Epoch 14714:  Error = 0.406678
# Epoch 14715:  Error = 0.406656
# Epoch 14716:  Error = 0.406635
# Epoch 14717:  Error = 0.406614
# Epoch 14718:  Error = 0.406593
# Epoch 14719:  Error = 0.406572
# Epoch 14720:  Error = 0.406551
# Epoch 14721:  Error = 0.406530
# Epoch 14722:  Error = 0.406508
# Epoch 14723:  Error = 0.406487
# Epoch 14724:  Error = 0.406466
# Epoch 14725:  Error = 0.406445
# Epoch 14726:  Error = 0.406424
# Epoch 14727:  Error = 0.406403
# Epoch 14728:  Error = 0.406382
# Epoch 14729:  Error = 0.406360
# Epoch 14730:  Error = 0.406339
# Epoch 14731:  Error = 0.406318
# Epoch 14732:  Error = 0.406297
# Epoch 14733:  Error = 0.406276
# Epoch 14734:  Error = 0.406255
# Epoch 14735:  Error = 0.406234
# Epoch 14736:  Error = 0.406213
# Epoch 14737:  Error = 0.406192
# Epoch 14738:  Error = 0.406170
# Epoch 14739:  Error = 0.406149
# Epoch 14740:  Error = 0.406128
# Epoch 14741:  Error = 0.406107
# Epoch 14742:  Error = 0.406086
# Epoch 14743:  Error = 0.406065
# Epoch 14744:  Error = 0.406044
# Epoch 14745:  Error = 0.406023
# Epoch 14746:  Error = 0.406002
# Epoch 14747:  Error = 0.405981
# Epoch 14748:  Error = 0.405960
# Epoch 14749:  Error = 0.405939
# Epoch 14750:  Error = 0.405917
# Epoch 14751:  Error = 0.405896
# Epoch 14752:  Error = 0.405875
# Epoch 14753:  Error = 0.405854
# Epoch 14754:  Error = 0.405833
# Epoch 14755:  Error = 0.405812
# Epoch 14756:  Error = 0.405791
# Epoch 14757:  Error = 0.405770
# Epoch 14758:  Error = 0.405749
# Epoch 14759:  Error = 0.405728
# Epoch 14760:  Error = 0.405707
# Epoch 14761:  Error = 0.405686
# Epoch 14762:  Error = 0.405665
# Epoch 14763:  Error = 0.405644
# Epoch 14764:  Error = 0.405623
# Epoch 14765:  Error = 0.405602
# Epoch 14766:  Error = 0.405581
# Epoch 14767:  Error = 0.405560
# Epoch 14768:  Error = 0.405539
# Epoch 14769:  Error = 0.405518
# Epoch 14770:  Error = 0.405497
# Epoch 14771:  Error = 0.405475
# Epoch 14772:  Error = 0.405454
# Epoch 14773:  Error = 0.405433
# Epoch 14774:  Error = 0.405412
# Epoch 14775:  Error = 0.405391
# Epoch 14776:  Error = 0.405370
# Epoch 14777:  Error = 0.405349
# Epoch 14778:  Error = 0.405328
# Epoch 14779:  Error = 0.405307
# Epoch 14780:  Error = 0.405286
# Epoch 14781:  Error = 0.405265
# Epoch 14782:  Error = 0.405244
# Epoch 14783:  Error = 0.405223
# Epoch 14784:  Error = 0.405202
# Epoch 14785:  Error = 0.405181
# Epoch 14786:  Error = 0.405160
# Epoch 14787:  Error = 0.405140
# Epoch 14788:  Error = 0.405119
# Epoch 14789:  Error = 0.405098
# Epoch 14790:  Error = 0.405077
# Epoch 14791:  Error = 0.405056
# Epoch 14792:  Error = 0.405035
# Epoch 14793:  Error = 0.405014
# Epoch 14794:  Error = 0.404993
# Epoch 14795:  Error = 0.404972
# Epoch 14796:  Error = 0.404951
# Epoch 14797:  Error = 0.404930
# Epoch 14798:  Error = 0.404909
# Epoch 14799:  Error = 0.404888
# Epoch 14800:  Error = 0.404867
# Epoch 14801:  Error = 0.404846
# Epoch 14802:  Error = 0.404825
# Epoch 14803:  Error = 0.404804
# Epoch 14804:  Error = 0.404783
# Epoch 14805:  Error = 0.404762
# Epoch 14806:  Error = 0.404741
# Epoch 14807:  Error = 0.404720
# Epoch 14808:  Error = 0.404700
# Epoch 14809:  Error = 0.404679
# Epoch 14810:  Error = 0.404658
# Epoch 14811:  Error = 0.404637
# Epoch 14812:  Error = 0.404616
# Epoch 14813:  Error = 0.404595
# Epoch 14814:  Error = 0.404574
# Epoch 14815:  Error = 0.404553
# Epoch 14816:  Error = 0.404532
# Epoch 14817:  Error = 0.404511
# Epoch 14818:  Error = 0.404490
# Epoch 14819:  Error = 0.404469
# Epoch 14820:  Error = 0.404449
# Epoch 14821:  Error = 0.404428
# Epoch 14822:  Error = 0.404407
# Epoch 14823:  Error = 0.404386
# Epoch 14824:  Error = 0.404365
# Epoch 14825:  Error = 0.404344
# Epoch 14826:  Error = 0.404323
# Epoch 14827:  Error = 0.404302
# Epoch 14828:  Error = 0.404282
# Epoch 14829:  Error = 0.404261
# Epoch 14830:  Error = 0.404240
# Epoch 14831:  Error = 0.404219
# Epoch 14832:  Error = 0.404198
# Epoch 14833:  Error = 0.404177
# Epoch 14834:  Error = 0.404156
# Epoch 14835:  Error = 0.404135
# Epoch 14836:  Error = 0.404115
# Epoch 14837:  Error = 0.404094
# Epoch 14838:  Error = 0.404073
# Epoch 14839:  Error = 0.404052
# Epoch 14840:  Error = 0.404031
# Epoch 14841:  Error = 0.404010
# Epoch 14842:  Error = 0.403989
# Epoch 14843:  Error = 0.403969
# Epoch 14844:  Error = 0.403948
# Epoch 14845:  Error = 0.403927
# Epoch 14846:  Error = 0.403906
# Epoch 14847:  Error = 0.403885
# Epoch 14848:  Error = 0.403864
# Epoch 14849:  Error = 0.403844
# Epoch 14850:  Error = 0.403823
# Epoch 14851:  Error = 0.403802
# Epoch 14852:  Error = 0.403781
# Epoch 14853:  Error = 0.403760
# Epoch 14854:  Error = 0.403740
# Epoch 14855:  Error = 0.403719
# Epoch 14856:  Error = 0.403698
# Epoch 14857:  Error = 0.403677
# Epoch 14858:  Error = 0.403656
# Epoch 14859:  Error = 0.403636
# Epoch 14860:  Error = 0.403615
# Epoch 14861:  Error = 0.403594
# Epoch 14862:  Error = 0.403573
# Epoch 14863:  Error = 0.403552
# Epoch 14864:  Error = 0.403532
# Epoch 14865:  Error = 0.403511
# Epoch 14866:  Error = 0.403490
# Epoch 14867:  Error = 0.403469
# Epoch 14868:  Error = 0.403448
# Epoch 14869:  Error = 0.403428
# Epoch 14870:  Error = 0.403407
# Epoch 14871:  Error = 0.403386
# Epoch 14872:  Error = 0.403365
# Epoch 14873:  Error = 0.403345
# Epoch 14874:  Error = 0.403324
# Epoch 14875:  Error = 0.403303
# Epoch 14876:  Error = 0.403282
# Epoch 14877:  Error = 0.403262
# Epoch 14878:  Error = 0.403241
# Epoch 14879:  Error = 0.403220
# Epoch 14880:  Error = 0.403199
# Epoch 14881:  Error = 0.403179
# Epoch 14882:  Error = 0.403158
# Epoch 14883:  Error = 0.403137
# Epoch 14884:  Error = 0.403116
# Epoch 14885:  Error = 0.403096
# Epoch 14886:  Error = 0.403075
# Epoch 14887:  Error = 0.403054
# Epoch 14888:  Error = 0.403033
# Epoch 14889:  Error = 0.403013
# Epoch 14890:  Error = 0.402992
# Epoch 14891:  Error = 0.402971
# Epoch 14892:  Error = 0.402951
# Epoch 14893:  Error = 0.402930
# Epoch 14894:  Error = 0.402909
# Epoch 14895:  Error = 0.402888
# Epoch 14896:  Error = 0.402868
# Epoch 14897:  Error = 0.402847
# Epoch 14898:  Error = 0.402826
# Epoch 14899:  Error = 0.402806
# Epoch 14900:  Error = 0.402785
# Epoch 14901:  Error = 0.402764
# Epoch 14902:  Error = 0.402743
# Epoch 14903:  Error = 0.402723
# Epoch 14904:  Error = 0.402702
# Epoch 14905:  Error = 0.402681
# Epoch 14906:  Error = 0.402661
# Epoch 14907:  Error = 0.402640
# Epoch 14908:  Error = 0.402619
# Epoch 14909:  Error = 0.402599
# Epoch 14910:  Error = 0.402578
# Epoch 14911:  Error = 0.402557
# Epoch 14912:  Error = 0.402537
# Epoch 14913:  Error = 0.402516
# Epoch 14914:  Error = 0.402495
# Epoch 14915:  Error = 0.402475
# Epoch 14916:  Error = 0.402454
# Epoch 14917:  Error = 0.402433
# Epoch 14918:  Error = 0.402413
# Epoch 14919:  Error = 0.402392
# Epoch 14920:  Error = 0.402371
# Epoch 14921:  Error = 0.402351
# Epoch 14922:  Error = 0.402330
# Epoch 14923:  Error = 0.402309
# Epoch 14924:  Error = 0.402289
# Epoch 14925:  Error = 0.402268
# Epoch 14926:  Error = 0.402248
# Epoch 14927:  Error = 0.402227
# Epoch 14928:  Error = 0.402206
# Epoch 14929:  Error = 0.402186
# Epoch 14930:  Error = 0.402165
# Epoch 14931:  Error = 0.402144
# Epoch 14932:  Error = 0.402124
# Epoch 14933:  Error = 0.402103
# Epoch 14934:  Error = 0.402083
# Epoch 14935:  Error = 0.402062
# Epoch 14936:  Error = 0.402041
# Epoch 14937:  Error = 0.402021
# Epoch 14938:  Error = 0.402000
# Epoch 14939:  Error = 0.401980
# Epoch 14940:  Error = 0.401959
# Epoch 14941:  Error = 0.401938
# Epoch 14942:  Error = 0.401918
# Epoch 14943:  Error = 0.401897
# Epoch 14944:  Error = 0.401877
# Epoch 14945:  Error = 0.401856
# Epoch 14946:  Error = 0.401835
# Epoch 14947:  Error = 0.401815
# Epoch 14948:  Error = 0.401794
# Epoch 14949:  Error = 0.401774
# Epoch 14950:  Error = 0.401753
# Epoch 14951:  Error = 0.401732
# Epoch 14952:  Error = 0.401712
# Epoch 14953:  Error = 0.401691
# Epoch 14954:  Error = 0.401671
# Epoch 14955:  Error = 0.401650
# Epoch 14956:  Error = 0.401630
# Epoch 14957:  Error = 0.401609
# Epoch 14958:  Error = 0.401589
# Epoch 14959:  Error = 0.401568
# Epoch 14960:  Error = 0.401547
# Epoch 14961:  Error = 0.401527
# Epoch 14962:  Error = 0.401506
# Epoch 14963:  Error = 0.401486
# Epoch 14964:  Error = 0.401465
# Epoch 14965:  Error = 0.401445
# Epoch 14966:  Error = 0.401424
# Epoch 14967:  Error = 0.401404
# Epoch 14968:  Error = 0.401383
# Epoch 14969:  Error = 0.401363
# Epoch 14970:  Error = 0.401342
# Epoch 14971:  Error = 0.401322
# Epoch 14972:  Error = 0.401301
# Epoch 14973:  Error = 0.401280
# Epoch 14974:  Error = 0.401260
# Epoch 14975:  Error = 0.401239
# Epoch 14976:  Error = 0.401219
# Epoch 14977:  Error = 0.401198
# Epoch 14978:  Error = 0.401178
# Epoch 14979:  Error = 0.401157
# Epoch 14980:  Error = 0.401137
# Epoch 14981:  Error = 0.401116
# Epoch 14982:  Error = 0.401096
# Epoch 14983:  Error = 0.401075
# Epoch 14984:  Error = 0.401055
# Epoch 14985:  Error = 0.401034
# Epoch 14986:  Error = 0.401014
# Epoch 14987:  Error = 0.400993
# Epoch 14988:  Error = 0.400973
# Epoch 14989:  Error = 0.400952
# Epoch 14990:  Error = 0.400932
# Epoch 14991:  Error = 0.400912
# Epoch 14992:  Error = 0.400891
# Epoch 14993:  Error = 0.400871
# Epoch 14994:  Error = 0.400850
# Epoch 14995:  Error = 0.400830
# Epoch 14996:  Error = 0.400809
# Epoch 14997:  Error = 0.400789
# Epoch 14998:  Error = 0.400768
# Epoch 14999:  Error = 0.400748
# Epoch 15000:  Error = 0.400727
# Epoch 15001:  Error = 0.400707
# Epoch 15002:  Error = 0.400686
# Epoch 15003:  Error = 0.400666
# Epoch 15004:  Error = 0.400646
# Epoch 15005:  Error = 0.400625
# Epoch 15006:  Error = 0.400605
# Epoch 15007:  Error = 0.400584
# Epoch 15008:  Error = 0.400564
# Epoch 15009:  Error = 0.400543
# Epoch 15010:  Error = 0.400523
# Epoch 15011:  Error = 0.400502
# Epoch 15012:  Error = 0.400482
# Epoch 15013:  Error = 0.400462
# Epoch 15014:  Error = 0.400441
# Epoch 15015:  Error = 0.400421
# Epoch 15016:  Error = 0.400400
# Epoch 15017:  Error = 0.400380
# Epoch 15018:  Error = 0.400360
# Epoch 15019:  Error = 0.400339
# Epoch 15020:  Error = 0.400319
# Epoch 15021:  Error = 0.400298
# Epoch 15022:  Error = 0.400278
# Epoch 15023:  Error = 0.400258
# Epoch 15024:  Error = 0.400237
# Epoch 15025:  Error = 0.400217
# Epoch 15026:  Error = 0.400196
# Epoch 15027:  Error = 0.400176
# Epoch 15028:  Error = 0.400156
# Epoch 15029:  Error = 0.400135
# Epoch 15030:  Error = 0.400115
# Epoch 15031:  Error = 0.400094
# Epoch 15032:  Error = 0.400074
# Epoch 15033:  Error = 0.400054
# Epoch 15034:  Error = 0.400033
# Epoch 15035:  Error = 0.400013
# Epoch 15036:  Error = 0.399993

# %% [markdown]
# **Optional questions**
#
# 2. *Weight decay* constraint
#
# As nothing constrains the weights in the network, we can note that usually all weights vector given a multiplicative factor might be equivalent, which can stall the learning (and lead to exploding weights). The *weight decay* allows to regularize the learning by penalizing weights with a too wide amplitude. The idea is to add this constraint as a term to the final loss (which leads to an indirect "pressure" on the learning process. Therefore, the final loss will be defined as
#
# $$
# \begin{equation}
# \mathcal{L}_{final}=\mathcal{L_D} + \lambda \sum_{l} \sum_{i} \sum_{j} \left( W_{ij}^{l} \right)^{2}
# \end{equation}
# $$
#
# where the parameter $\lambda$ controls the relative importance of the two terms.
#
# 3. *Momentum* in learning
#
# Usually, in complex problems, the gradient can be very noisy and, therefore, the learning might oscillate widely. In order to reduce this problem, we can *smooth* the different gradient updates by retaining the values of the gradient at each iteration and then performing an update based on the latest gradient $\delta_{i}^{t}$ and the gradient at the previous iteration $\delta_{i}^{t-1}$. Therefore, a gradient update is applied as
#
# $$
# \begin{equation}
# \delta_{final}^{t} = \delta_{i}^{t} + m.\delta_{i}^{t-1}
# \end{equation}
# $$
#
# with $m$ the momentum parameter, which control the amount of gradient smoothing.

# %% [markdown]
# ## 3-layer audio classification : OBLIGATOIRE
#
# Finally, we will attack a complete audio classification problem and try to perform neural network learning on a set of audio files. The data structure will be the same as the one used for parts 1 and 2. As discussed during the courses, even though a 2-layer neural network can provide non-linear boundaries, it can not perform "holes" inside those regions. In order to obtain an improved classification, we will now rely on a 3-layer neural network. The modification to the code of section 3.2 should be minimal, as the back-propagation will be similar for the new layer as one of the two others. We do not develop the math here as it is simply a re-application of the previous rules with an additional layer (which derivatives you should have generalized in the previous exercise).
#
# However, up until now, we only performed *binary classification* problems, but this time we need to obtain a decision rule for multiple classes. Therefore, we cannot rely on simply computing the distance between desired patterns and the obtained binary value. The idea here is to rely on the *softmax regression*, by considering classes as a vector of probabilities. The desired answers will therefore be considered as a set of *probabilities*, where the desired class is $1$ and the others are $0$ (called *one-hot* representation). Then, the cost function will rely on the softmax formulation
#
# $$
# \begin{equation}
# \mathcal{L_D}(\theta) = - \frac{1}{m} \left[ \sum_{i=1}^{m} \sum_{j=1}^{k} 1\left\{y^{(i)} = j\right\} log \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)} }}  \right]
# \end{equation}
# $$
#
# Therefore, we compute the output of the softmax by taking
#
# $$
# \begin{equation}
# p(y^{(i)} = j | x^{(i)}; \theta) = \frac{e^{\theta_{j}^{T} x^{(i)}}}{\sum_{l=1}^{k} e^{ \theta_{l}^{T} x^{(i)}} }
# \end{equation}
# $$
#
# By taking derivatives, we can show that the gradient of the softmax layer is
#
# $$
# \begin{equation}
# \nabla_{\theta_{j}} \mathcal{L_D}(\theta) = - \frac{1}{m} \sum_{i=1}^{m}{ \left[ x^{(i)} \left( 1\{ y^{(i)} = j\}  - p(y^{(i)} = j \mid x^{(i)}, \theta) \right) \right]}
# \end{equation}
# $$

# %% [markdown]
# ### Sweet activation functions
#
# As discussed in the course, the interest of stacking layers is that there is an _activation function_, which allows non-linear interactions between the dimensions (and avoids to only compute a single huge affine transform). Although the `sigmoid` function has been historically the most used, there has been some large developments since. Notably the `ReLU` (Rectified Linear Unit) is one of the major difference in modern networks (we will see more about that in a later course)

# %%
# Function for computing the Sigmoid activation
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
def dsigmoid(a):
    return a * (1.0 - a)
# Function for computing the ReLU activation
def relu(x):
    return np.maximum(0, x)
def drelu(x):
    return 1 / (1 + np.exp(-x))
# Function for computing the Tanh activation
def tanh(x):
    return np.tanh(x);
def dtanh(x): 
    return np.cosh(x) ^ -2

# %% [markdown]
# Here, we plot some simple examples of what these activation functions look like. You can try to rely on these functions in your previous training code and witness the differences in training.

# %%
from helper_plot import prep_plots, finalize_plots
funcs = [('sigmoid',sigmoid,'red'), ('tanh',tanh,'orange'), ('relu',relu,'yellow')]
axes = prep_plots([funcs[0][0], funcs[1][0], funcs[2][0]], fig_size=(18,5), fig_num=1)
x_plot = np.linspace(-5,5,100)
np.maximum(0, x_plot)
for f in range(3):
    axes[f].plot(x_plot, funcs[f][1](x_plot), color=funcs[f][2], linewidth=4, label=funcs[f][0])
finalize_plots(axes, fig_title="Activation functions")

# %% [markdown]
# ## Coding the whole network from scratch
#
# You should now have all the tools necessary to apply neural networks from scratch to a more complex problem. In the following exercise, we simply removed any guideline code, and you need to code all the procedure for training a NN and **apply it to audio data**. You will use the spectral features discussed in the previous exercise as an input.
#
# ***
#
# **Exercise**
#
#   1. Based on the previous neural network, upgrade the code to a 3-layer neural network
#   2. Implement the *softmax regression* on top of your 3-layer network
#   3. Use the provided code to perform classification on a pre-defined set of features
#   4. As previously, change the set of features to assess their different accuracies
#   5. Evaluate the neural network accuracy for all features combinations
#   6. What happens if the learning rate is too large ? What is this phenomenon ?
#   7. (Optional) Perform a more advanced visualization of the learning process.
#
# ***

# %%
class_path = 'data/classification';
from helper_data import import_dataset, compute_features, compute_transforms
data_struct = import_dataset(class_path, 'classification')
data_struct = compute_transforms(data_struct)
data_struct = compute_features(data_struct)
# Out:
# /usr/local/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (5.0.0)/charset_normalizer (2.0.11) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "
#     - Importing dataset data/classification.
#
#     - Performing transforms.
#     - Performing features.

# %%
data_struct.keys()
# Out:
# dict_keys(['filenames', 'classes', 'class_names', 'signal', 'srate', 'spectrum_power', 'spectrum_mel', 'spectrum_chroma', 'spectrum_CQT', 'features_spectral', 'loudness', 'loudness_mean', 'loudness_std', 'spectral_centroid', 'spectral_centroid_mean', 'spectral_centroid_std', 'spectral_bandwidth', 'spectral_bandwidth_mean', 'spectral_bandwidth_std', 'spectral_contrast', 'spectral_contrast_mean', 'spectral_contrast_std', 'spectral_flatness', 'spectral_flatness_mean', 'spectral_flatness_std', 'spectral_rolloff', 'spectral_rolloff_mean', 'spectral_rolloff_std'])

# %%
num_classes = len(data_struct['class_names'])
class_counter = np.zeros(num_classes,dtype=int)
for i in range(num_classes) :
    for j in data_struct['classes'] :
        if i==j :
            class_counter[i] += 1

# %% [markdown]
# On décide de comparer dans un premier temps les bells avec les speech males

# %%
sc_mean = data_struct['spectral_centroid_mean'][0:class_counter[0]+class_counter[1]]
sc_std = data_struct['spectral_centroid_std'][0:class_counter[0]+class_counter[1]]
sb_std = data_struct['spectral_bandwidth_std'][0:class_counter[0]+class_counter[1]]
sb_mean = data_struct['spectral_bandwidth_mean'][0:class_counter[0]+class_counter[1]]
scont_mean = data_struct['spectral_contrast_mean'][0:class_counter[0]+class_counter[1]]
scont_std = data_struct['spectral_contrast_std'][0:class_counter[0]+class_counter[1]]

# %%
#inputs = np.concatenate([sc_mean,sc_std,sb_std,sb_mean,scont_mean,scont_std])
inputs = np.concatenate([sc_mean,sc_std])
inputs = inputs.reshape((2,class_counter[0]+class_counter[1]))
inputs = inputs.T

desired = np.concatenate([np.zeros(class_counter[0]),np.ones(class_counter[1])])

# %%
nHiddens1 = 3
nHiddens2 = 3

nInputs = inputs.shape[1]

weights1 = (np.random.randn(nHiddens1, nInputs) - 0.5)      # 1st layer weights
weights2 = (np.random.randn(nHiddens2, nHiddens1) - 0.5)     # 2nd layer weights
weights3 = (np.random.randn(nOutputs, nHiddens2) - 0.5)     # 3nd layer weights
bias1 = (np.random.randn(nHiddens1, 1) - 0.5)               # 1st layer biases
bias2 = (np.random.randn(nHiddens2, 1) - 0.5)               # 2nd layer biases
bias3 = (np.random.randn(nOutputs, 1) - 0.5)               # 3nd layer biases

eta = 0.1

# %%
fig = plt.figure()
plt.scatter(inputs[:class_counter[0],0],inputs[:class_counter[0],1],label="bells")
plt.scatter(inputs[class_counter[0]:class_counter[0]+class_counter[1],0],inputs[class_counter[0]:class_counter[0]+class_counter[1],1],label="speech male")
plt.grid()
plt.legend()
plt.xlabel("")
plt.ylabel("")
plt.title(r"")
plt.xlim()
plt.ylim()
# Out:
# (-38.22147277717879, 1668.9078878698629)

# %%
for epoch in range(10000):
    #Forward
    y1 = sigmoid(np.matmul(weights1,inputs.T) + bias1)
    y2 = sigmoid(np.matmul(weights2,y1) + bias2)
    y3 = sigmoid(np.matmul(weights3,y2) + bias3)
    
    #Derivatives
    dphi1 = dsigmoid(y1)
    dphi2 = dsigmoid(y2)
    dphi3 = dsigmoid(y3)
    dw3 = 2 * np.matmul((dphi3 * (y3-desired)),y2.T)
    dw2 = 2 * np.matmul(np.dot(weights3, dphi2 * dphi3 * (y3-desired)),y1.T)
    dw1 = 2 * np.matmul(np.dot(weights3, np.dot(weights2, dphi1 * dphi2 * dphi3 * (y3-desired))),inputs)
    
    dbias3 = np.sum(2 * (dphi3 * (y3-desired)))
    dbias2 = np.sum(2 * np.dot(weights3, dphi2 * dphi3 * (y3-desired)))
    dbias1 = np.sum(2 * np.dot(weights2, np.dot(weights2, dphi1 * dphi2 * dphi3 * (y3-desired))))

    #Backward
    weights1 -= eta * dw1
    weights2 -= eta * dw2
    
    bias1 -= eta * dbias1
    bias2 -= eta * dbias2
    
    TSS = np.sum(np.square((desired-y2)))
    
    
    print('Epoch %3d:  Error = %f' % (epoch, TSS))
    if TSS < TSS_Limit:
        break
    if (epoch - 1 % 20)==0:
        plot_boundary(np.concatenate((bias3, weights3), axis=1), epoch, '--', fig)

plot_boundary(np.concatenate((bias1, weights1), axis=1), epoch, '-', fig)
# Out:
# Epoch   0:  Error = 33.284353
# Epoch   1:  Error = 35.862259
# Epoch   2:  Error = 38.985311
# Epoch   3:  Error = 42.105395
# Epoch   4:  Error = 44.483913
# Epoch   5:  Error = 46.031015
# Epoch   6:  Error = 47.030449
# Epoch   7:  Error = 47.708400
# Epoch   8:  Error = 48.192875
# Epoch   9:  Error = 48.554585
# Epoch  10:  Error = 48.834306
# Epoch  11:  Error = 49.056823
# Epoch  12:  Error = 49.237945
# Epoch  13:  Error = 49.388190
# Epoch  14:  Error = 49.514811
# Epoch  15:  Error = 49.622963
# Epoch  16:  Error = 49.716406
# Epoch  17:  Error = 49.797948
# Epoch  18:  Error = 49.869726
# Epoch  19:  Error = 49.933394
# Epoch  20:  Error = 49.990255
# Epoch  21:  Error = 50.041344
# Epoch  22:  Error = 50.087500
# Epoch  23:  Error = 50.129403
# Epoch  24:  Error = 50.167617
# Epoch  25:  Error = 50.202608
# Epoch  26:  Error = 50.234768
# Epoch  27:  Error = 50.264428
# Epoch  28:  Error = 50.291869
# Epoch  29:  Error = 50.317330
# Epoch  30:  Error = 50.341020
# Epoch  31:  Error = 50.363116
# Epoch  32:  Error = 50.383775
# Epoch  33:  Error = 50.403133
# Epoch  34:  Error = 50.421309
# Epoch  35:  Error = 50.438407
# Epoch  36:  Error = 50.454522
# Epoch  37:  Error = 50.469736
# Epoch  38:  Error = 50.484122
# Epoch  39:  Error = 50.497747
# Epoch  40:  Error = 50.510669
# Epoch  41:  Error = 50.522941
# Epoch  42:  Error = 50.534611
# Epoch  43:  Error = 50.545723
# Epoch  44:  Error = 50.556315
# Epoch  45:  Error = 50.566424
# Epoch  46:  Error = 50.576082
# Epoch  47:  Error = 50.585317
# Epoch  48:  Error = 50.594159
# Epoch  49:  Error = 50.602630
# Epoch  50:  Error = 50.610754
# Epoch  51:  Error = 50.618552
# Epoch  52:  Error = 50.626043
# Epoch  53:  Error = 50.633245
# Epoch  54:  Error = 50.640175
# Epoch  55:  Error = 50.646847
# Epoch  56:  Error = 50.653275
# Epoch  57:  Error = 50.659474
# Epoch  58:  Error = 50.665454
# Epoch  59:  Error = 50.671227
# Epoch  60:  Error = 50.676804
# Epoch  61:  Error = 50.682195
# Epoch  62:  Error = 50.687409
# Epoch  63:  Error = 50.692454
# Epoch  64:  Error = 50.697339
# Epoch  65:  Error = 50.702070
# Epoch  66:  Error = 50.706656
# Epoch  67:  Error = 50.711103
# Epoch  68:  Error = 50.715416
# Epoch  69:  Error = 50.719603
# Epoch  70:  Error = 50.723667
# Epoch  71:  Error = 50.727616
# Epoch  72:  Error = 50.731453
# Epoch  73:  Error = 50.735183
# Epoch  74:  Error = 50.738811
# Epoch  75:  Error = 50.742341
# Epoch  76:  Error = 50.745777
# Epoch  77:  Error = 50.749122
# Epoch  78:  Error = 50.752380
# Epoch  79:  Error = 50.755554
# Epoch  80:  Error = 50.758648
# Epoch  81:  Error = 50.761664
# Epoch  82:  Error = 50.764606
# Epoch  83:  Error = 50.767476
# Epoch  84:  Error = 50.770277
# Epoch  85:  Error = 50.773011
# Epoch  86:  Error = 50.775681
# Epoch  87:  Error = 50.778288
# Epoch  88:  Error = 50.780836
# Epoch  89:  Error = 50.783325
# Epoch  90:  Error = 50.785759
# Epoch  91:  Error = 50.788138
# Epoch  92:  Error = 50.790466
# Epoch  93:  Error = 50.792742
# Epoch  94:  Error = 50.794970
# Epoch  95:  Error = 50.797150
# Epoch  96:  Error = 50.799284
# Epoch  97:  Error = 50.801373
# Epoch  98:  Error = 50.803420
# Epoch  99:  Error = 50.805425
# Epoch 100:  Error = 50.807389
# Epoch 101:  Error = 50.809314
# Epoch 102:  Error = 50.811201
# Epoch 103:  Error = 50.813051
# Epoch 104:  Error = 50.814864
# Epoch 105:  Error = 50.816643
# Epoch 106:  Error = 50.818389
# Epoch 107:  Error = 50.820101
# Epoch 108:  Error = 50.821781
# Epoch 109:  Error = 50.823430
# Epoch 110:  Error = 50.825049
# Epoch 111:  Error = 50.826638
# Epoch 112:  Error = 50.828198
# Epoch 113:  Error = 50.829731
# Epoch 114:  Error = 50.831237
# Epoch 115:  Error = 50.832716
# Epoch 116:  Error = 50.834170
# Epoch 117:  Error = 50.835598
# Epoch 118:  Error = 50.837002
# Epoch 119:  Error = 50.838382
# Epoch 120:  Error = 50.839739
# Epoch 121:  Error = 50.841074
# Epoch 122:  Error = 50.842386
# Epoch 123:  Error = 50.843677
# Epoch 124:  Error = 50.844947
# Epoch 125:  Error = 50.846196
# Epoch 126:  Error = 50.847425
# Epoch 127:  Error = 50.848635
# Epoch 128:  Error = 50.849826
# Epoch 129:  Error = 50.850998
# Epoch 130:  Error = 50.852152
# Epoch 131:  Error = 50.853288
# Epoch 132:  Error = 50.854407
# Epoch 133:  Error = 50.855509
# Epoch 134:  Error = 50.856595
# Epoch 135:  Error = 50.857664
# Epoch 136:  Error = 50.858717
# Epoch 137:  Error = 50.859755
# Epoch 138:  Error = 50.860778
# Epoch 139:  Error = 50.861786
# Epoch 140:  Error = 50.862779
# Epoch 141:  Error = 50.863758
# Epoch 142:  Error = 50.864724
# Epoch 143:  Error = 50.865675
# Epoch 144:  Error = 50.866614
# Epoch 145:  Error = 50.867539
# Epoch 146:  Error = 50.868452
# Epoch 147:  Error = 50.869352
# Epoch 148:  Error = 50.870240
# Epoch 149:  Error = 50.871116
# Epoch 150:  Error = 50.871980
# Epoch 151:  Error = 50.872832
# Epoch 152:  Error = 50.873674
# Epoch 153:  Error = 50.874504
# Epoch 154:  Error = 50.875323
# Epoch 155:  Error = 50.876132
# Epoch 156:  Error = 50.876931
# Epoch 157:  Error = 50.877719
# Epoch 158:  Error = 50.878497
# Epoch 159:  Error = 50.879265
# Epoch 160:  Error = 50.880023
# Epoch 161:  Error = 50.880773
# Epoch 162:  Error = 50.881512
# Epoch 163:  Error = 50.882243
# Epoch 164:  Error = 50.882965
# Epoch 165:  Error = 50.883678
# Epoch 166:  Error = 50.884382
# Epoch 167:  Error = 50.885078
# Epoch 168:  Error = 50.885765
# Epoch 169:  Error = 50.886444
# Epoch 170:  Error = 50.887116
# Epoch 171:  Error = 50.887779
# Epoch 172:  Error = 50.888434
# Epoch 173:  Error = 50.889082
# Epoch 174:  Error = 50.889723
# Epoch 175:  Error = 50.890356
# Epoch 176:  Error = 50.890982
# Epoch 177:  Error = 50.891601
# Epoch 178:  Error = 50.892212
# Epoch 179:  Error = 50.892817
# Epoch 180:  Error = 50.893415
# Epoch 181:  Error = 50.894007
# Epoch 182:  Error = 50.894592
# Epoch 183:  Error = 50.895170
# Epoch 184:  Error = 50.895743
# Epoch 185:  Error = 50.896309
# Epoch 186:  Error = 50.896869
# Epoch 187:  Error = 50.897422
# Epoch 188:  Error = 50.897970
# Epoch 189:  Error = 50.898513
# Epoch 190:  Error = 50.899049
# Epoch 191:  Error = 50.899580
# Epoch 192:  Error = 50.900105
# Epoch 193:  Error = 50.900625
# Epoch 194:  Error = 50.901139
# Epoch 195:  Error = 50.901648
# Epoch 196:  Error = 50.902152
# Epoch 197:  Error = 50.902651
# Epoch 198:  Error = 50.903144
# Epoch 199:  Error = 50.903633
# Epoch 200:  Error = 50.904117
# Epoch 201:  Error = 50.904595
# Epoch 202:  Error = 50.905070
# Epoch 203:  Error = 50.905539
# Epoch 204:  Error = 50.906004
# Epoch 205:  Error = 50.906464
# Epoch 206:  Error = 50.906920
# Epoch 207:  Error = 50.907371
# Epoch 208:  Error = 50.907818
# Epoch 209:  Error = 50.908261
# Epoch 210:  Error = 50.908699
# Epoch 211:  Error = 50.909134
# Epoch 212:  Error = 50.909564
# Epoch 213:  Error = 50.909990
# Epoch 214:  Error = 50.910412
# Epoch 215:  Error = 50.910830
# Epoch 216:  Error = 50.911245
# Epoch 217:  Error = 50.911655
# Epoch 218:  Error = 50.912062
# Epoch 219:  Error = 50.912465
# Epoch 220:  Error = 50.912864
# Epoch 221:  Error = 50.913260
# Epoch 222:  Error = 50.913652
# Epoch 223:  Error = 50.914040
# Epoch 224:  Error = 50.914425
# Epoch 225:  Error = 50.914807
# Epoch 226:  Error = 50.915185
# Epoch 227:  Error = 50.915560
# Epoch 228:  Error = 50.915932
# Epoch 229:  Error = 50.916300
# Epoch 230:  Error = 50.916665
# Epoch 231:  Error = 50.917027
# Epoch 232:  Error = 50.917386
# Epoch 233:  Error = 50.917742
# Epoch 234:  Error = 50.918094
# Epoch 235:  Error = 50.918444
# Epoch 236:  Error = 50.918791
# Epoch 237:  Error = 50.919134
# Epoch 238:  Error = 50.919475
# Epoch 239:  Error = 50.919813
# Epoch 240:  Error = 50.920148
# Epoch 241:  Error = 50.920481
# Epoch 242:  Error = 50.920810
# Epoch 243:  Error = 50.921137
# Epoch 244:  Error = 50.921461
# Epoch 245:  Error = 50.921783
# Epoch 246:  Error = 50.922102
# Epoch 247:  Error = 50.922418
# Epoch 248:  Error = 50.922732
# Epoch 249:  Error = 50.923043
# Epoch 250:  Error = 50.923352
# Epoch 251:  Error = 50.923658
# Epoch 252:  Error = 50.923962
# Epoch 253:  Error = 50.924263
# Epoch 254:  Error = 50.924562
# Epoch 255:  Error = 50.924859
# Epoch 256:  Error = 50.925153
# Epoch 257:  Error = 50.925445
# Epoch 258:  Error = 50.925735
# Epoch 259:  Error = 50.926023
# Epoch 260:  Error = 50.926308
# Epoch 261:  Error = 50.926591
# Epoch 262:  Error = 50.926872
# Epoch 263:  Error = 50.927151
# Epoch 264:  Error = 50.927428
# Epoch 265:  Error = 50.927702
# Epoch 266:  Error = 50.927975
# Epoch 267:  Error = 50.928245
# Epoch 268:  Error = 50.928514
# Epoch 269:  Error = 50.928780
# Epoch 270:  Error = 50.929045
# Epoch 271:  Error = 50.929307
# Epoch 272:  Error = 50.929568
# Epoch 273:  Error = 50.929827
# Epoch 274:  Error = 50.930083
# Epoch 275:  Error = 50.930338
# Epoch 276:  Error = 50.930591
# Epoch 277:  Error = 50.930842
# Epoch 278:  Error = 50.931092
# Epoch 279:  Error = 50.931339
# Epoch 280:  Error = 50.931585
# Epoch 281:  Error = 50.931829
# Epoch 282:  Error = 50.932072
# Epoch 283:  Error = 50.932312
# Epoch 284:  Error = 50.932551
# Epoch 285:  Error = 50.932789
# Epoch 286:  Error = 50.933024
# Epoch 287:  Error = 50.933258
# Epoch 288:  Error = 50.933490
# Epoch 289:  Error = 50.933721
# Epoch 290:  Error = 50.933950
# Epoch 291:  Error = 50.934178
# Epoch 292:  Error = 50.934404
# Epoch 293:  Error = 50.934628
# Epoch 294:  Error = 50.934851
# Epoch 295:  Error = 50.935072
# Epoch 296:  Error = 50.935292
# Epoch 297:  Error = 50.935511
# Epoch 298:  Error = 50.935727
# Epoch 299:  Error = 50.935943
# Epoch 300:  Error = 50.936157
# Epoch 301:  Error = 50.936370
# Epoch 302:  Error = 50.936581
# Epoch 303:  Error = 50.936791
# Epoch 304:  Error = 50.936999
# Epoch 305:  Error = 50.937206
# Epoch 306:  Error = 50.937412
# Epoch 307:  Error = 50.937616
# Epoch 308:  Error = 50.937819
# Epoch 309:  Error = 50.938021
# Epoch 310:  Error = 50.938221
# Epoch 311:  Error = 50.938420
# Epoch 312:  Error = 50.938618
# Epoch 313:  Error = 50.938814
# Epoch 314:  Error = 50.939010
# Epoch 315:  Error = 50.939204
# Epoch 316:  Error = 50.939397
# Epoch 317:  Error = 50.939588
# Epoch 318:  Error = 50.939779
# Epoch 319:  Error = 50.939968
# Epoch 320:  Error = 50.940156
# Epoch 321:  Error = 50.940343
# Epoch 322:  Error = 50.940528
# Epoch 323:  Error = 50.940713
# Epoch 324:  Error = 50.940896
# Epoch 325:  Error = 50.941078
# Epoch 326:  Error = 50.941259
# Epoch 327:  Error = 50.941439
# Epoch 328:  Error = 50.941618
# Epoch 329:  Error = 50.941796
# Epoch 330:  Error = 50.941973
# Epoch 331:  Error = 50.942149
# Epoch 332:  Error = 50.942323
# Epoch 333:  Error = 50.942497
# Epoch 334:  Error = 50.942669
# Epoch 335:  Error = 50.942841
# Epoch 336:  Error = 50.943011
# Epoch 337:  Error = 50.943181
# Epoch 338:  Error = 50.943349
# Epoch 339:  Error = 50.943516
# Epoch 340:  Error = 50.943683
# Epoch 341:  Error = 50.943848
# Epoch 342:  Error = 50.944013
# Epoch 343:  Error = 50.944176
# Epoch 344:  Error = 50.944339
# Epoch 345:  Error = 50.944501
# Epoch 346:  Error = 50.944661
# Epoch 347:  Error = 50.944821
# Epoch 348:  Error = 50.944980
# Epoch 349:  Error = 50.945138
# Epoch 350:  Error = 50.945295
# Epoch 351:  Error = 50.945451
# Epoch 352:  Error = 50.945606
# Epoch 353:  Error = 50.945761
# Epoch 354:  Error = 50.945914
# Epoch 355:  Error = 50.946067
# Epoch 356:  Error = 50.946219
# Epoch 357:  Error = 50.946370
# Epoch 358:  Error = 50.946520
# Epoch 359:  Error = 50.946669
# Epoch 360:  Error = 50.946817
# Epoch 361:  Error = 50.946965
# Epoch 362:  Error = 50.947112
# Epoch 363:  Error = 50.947258
# Epoch 364:  Error = 50.947403
# Epoch 365:  Error = 50.947547
# Epoch 366:  Error = 50.947691
# Epoch 367:  Error = 50.947834
# Epoch 368:  Error = 50.947976
# Epoch 369:  Error = 50.948117
# Epoch 370:  Error = 50.948257
# Epoch 371:  Error = 50.948397
# Epoch 372:  Error = 50.948536
# Epoch 373:  Error = 50.948674
# Epoch 374:  Error = 50.948812
# Epoch 375:  Error = 50.948948
# Epoch 376:  Error = 50.949084
# Epoch 377:  Error = 50.949220
# Epoch 378:  Error = 50.949354
# Epoch 379:  Error = 50.949488
# Epoch 380:  Error = 50.949621
# Epoch 381:  Error = 50.949754
# Epoch 382:  Error = 50.949885
# Epoch 383:  Error = 50.950016
# Epoch 384:  Error = 50.950147
# Epoch 385:  Error = 50.950277
# Epoch 386:  Error = 50.950406
# Epoch 387:  Error = 50.950534
# Epoch 388:  Error = 50.950662
# Epoch 389:  Error = 50.950789
# Epoch 390:  Error = 50.950915
# Epoch 391:  Error = 50.951041
# Epoch 392:  Error = 50.951166
# Epoch 393:  Error = 50.951290
# Epoch 394:  Error = 50.951414
# Epoch 395:  Error = 50.951537
# Epoch 396:  Error = 50.951660
# Epoch 397:  Error = 50.951782
# Epoch 398:  Error = 50.951903
# Epoch 399:  Error = 50.952024
# Epoch 400:  Error = 50.952144
# Epoch 401:  Error = 50.952264
# Epoch 402:  Error = 50.952383
# Epoch 403:  Error = 50.952501
# Epoch 404:  Error = 50.952619
# Epoch 405:  Error = 50.952736
# Epoch 406:  Error = 50.952852
# Epoch 407:  Error = 50.952968
# Epoch 408:  Error = 50.953084
# Epoch 409:  Error = 50.953199
# Epoch 410:  Error = 50.953313
# Epoch 411:  Error = 50.953427
# Epoch 412:  Error = 50.953540
# Epoch 413:  Error = 50.953653
# Epoch 414:  Error = 50.953765
# Epoch 415:  Error = 50.953876
# Epoch 416:  Error = 50.953987
# Epoch 417:  Error = 50.954098
# Epoch 418:  Error = 50.954208
# Epoch 419:  Error = 50.954317
# Epoch 420:  Error = 50.954426
# Epoch 421:  Error = 50.954535
# Epoch 422:  Error = 50.954643
# Epoch 423:  Error = 50.954750
# Epoch 424:  Error = 50.954857
# Epoch 425:  Error = 50.954963
# Epoch 426:  Error = 50.955069
# Epoch 427:  Error = 50.955174
# Epoch 428:  Error = 50.955279
# Epoch 429:  Error = 50.955384
# Epoch 430:  Error = 50.955488
# Epoch 431:  Error = 50.955591
# Epoch 432:  Error = 50.955694
# Epoch 433:  Error = 50.955797
# Epoch 434:  Error = 50.955899
# Epoch 435:  Error = 50.956000
# Epoch 436:  Error = 50.956101
# Epoch 437:  Error = 50.956202
# Epoch 438:  Error = 50.956302
# Epoch 439:  Error = 50.956401
# Epoch 440:  Error = 50.956501
# Epoch 441:  Error = 50.956599
# Epoch 442:  Error = 50.956698
# Epoch 443:  Error = 50.956796
# Epoch 444:  Error = 50.956893
# Epoch 445:  Error = 50.956990
# Epoch 446:  Error = 50.957087
# Epoch 447:  Error = 50.957183
# Epoch 448:  Error = 50.957279
# Epoch 449:  Error = 50.957374
# Epoch 450:  Error = 50.957469
# Epoch 451:  Error = 50.957563
# Epoch 452:  Error = 50.957657
# Epoch 453:  Error = 50.957751
# Epoch 454:  Error = 50.957844
# Epoch 455:  Error = 50.957937
# Epoch 456:  Error = 50.958029
# Epoch 457:  Error = 50.958121
# Epoch 458:  Error = 50.958213
# Epoch 459:  Error = 50.958304
# Epoch 460:  Error = 50.958394
# Epoch 461:  Error = 50.958485
# Epoch 462:  Error = 50.958575
# Epoch 463:  Error = 50.958664
# Epoch 464:  Error = 50.958754
# Epoch 465:  Error = 50.958842
# Epoch 466:  Error = 50.958931
# Epoch 467:  Error = 50.959019
# Epoch 468:  Error = 50.959107
# Epoch 469:  Error = 50.959194
# Epoch 470:  Error = 50.959281
# Epoch 471:  Error = 50.959367
# Epoch 472:  Error = 50.959454
# Epoch 473:  Error = 50.959539
# Epoch 474:  Error = 50.959625
# Epoch 475:  Error = 50.959710
# Epoch 476:  Error = 50.959795
# Epoch 477:  Error = 50.959879
# Epoch 478:  Error = 50.959963
# Epoch 479:  Error = 50.960047
# Epoch 480:  Error = 50.960130
# Epoch 481:  Error = 50.960213
# Epoch 482:  Error = 50.960296
# Epoch 483:  Error = 50.960378
# Epoch 484:  Error = 50.960460
# Epoch 485:  Error = 50.960542
# Epoch 486:  Error = 50.960623
# Epoch 487:  Error = 50.960704
# Epoch 488:  Error = 50.960785
# Epoch 489:  Error = 50.960865
# Epoch 490:  Error = 50.960945
# Epoch 491:  Error = 50.961024
# Epoch 492:  Error = 50.961104
# Epoch 493:  Error = 50.961183
# Epoch 494:  Error = 50.961261
# Epoch 495:  Error = 50.961340
# Epoch 496:  Error = 50.961418
# Epoch 497:  Error = 50.961495
# Epoch 498:  Error = 50.961573
# Epoch 499:  Error = 50.961650
# Epoch 500:  Error = 50.961727
# Epoch 501:  Error = 50.961803
# Epoch 502:  Error = 50.961879
# Epoch 503:  Error = 50.961955
# Epoch 504:  Error = 50.962031
# Epoch 505:  Error = 50.962106
# Epoch 506:  Error = 50.962181
# Epoch 507:  Error = 50.962256
# Epoch 508:  Error = 50.962330
# Epoch 509:  Error = 50.962404
# Epoch 510:  Error = 50.962478
# Epoch 511:  Error = 50.962552
# Epoch 512:  Error = 50.962625
# Epoch 513:  Error = 50.962698
# Epoch 514:  Error = 50.962770
# Epoch 515:  Error = 50.962843
# Epoch 516:  Error = 50.962915
# Epoch 517:  Error = 50.962987
# Epoch 518:  Error = 50.963058
# Epoch 519:  Error = 50.963129
# Epoch 520:  Error = 50.963200
# Epoch 521:  Error = 50.963271
# Epoch 522:  Error = 50.963342
# Epoch 523:  Error = 50.963412
# Epoch 524:  Error = 50.963482
# Epoch 525:  Error = 50.963551
# Epoch 526:  Error = 50.963621
# Epoch 527:  Error = 50.963690
# Epoch 528:  Error = 50.963759
# Epoch 529:  Error = 50.963827
# Epoch 530:  Error = 50.963896
# Epoch 531:  Error = 50.963964
# Epoch 532:  Error = 50.964031
# Epoch 533:  Error = 50.964099
# Epoch 534:  Error = 50.964166
# Epoch 535:  Error = 50.964233
# Epoch 536:  Error = 50.964300
# Epoch 537:  Error = 50.964367
# Epoch 538:  Error = 50.964433
# Epoch 539:  Error = 50.964499
# Epoch 540:  Error = 50.964565
# Epoch 541:  Error = 50.964630
# Epoch 542:  Error = 50.964696
# Epoch 543:  Error = 50.964761
# Epoch 544:  Error = 50.964826
# Epoch 545:  Error = 50.964890
# Epoch 546:  Error = 50.964955
# Epoch 547:  Error = 50.965019
# Epoch 548:  Error = 50.965083
# Epoch 549:  Error = 50.965146
# Epoch 550:  Error = 50.965210
# Epoch 551:  Error = 50.965273
# Epoch 552:  Error = 50.965336
# Epoch 553:  Error = 50.965399
# Epoch 554:  Error = 50.965461
# Epoch 555:  Error = 50.965523
# Epoch 556:  Error = 50.965586
# Epoch 557:  Error = 50.965647
# Epoch 558:  Error = 50.965709
# Epoch 559:  Error = 50.965770
# Epoch 560:  Error = 50.965832
# Epoch 561:  Error = 50.965893
# Epoch 562:  Error = 50.965953
# Epoch 563:  Error = 50.966014
# Epoch 564:  Error = 50.966074
# Epoch 565:  Error = 50.966134
# Epoch 566:  Error = 50.966194
# Epoch 567:  Error = 50.966254
# Epoch 568:  Error = 50.966313
# Epoch 569:  Error = 50.966373
# Epoch 570:  Error = 50.966432
# Epoch 571:  Error = 50.966490
# Epoch 572:  Error = 50.966549
# Epoch 573:  Error = 50.966608
# Epoch 574:  Error = 50.966666
# Epoch 575:  Error = 50.966724
# Epoch 576:  Error = 50.966782
# Epoch 577:  Error = 50.966839
# Epoch 578:  Error = 50.966897
# Epoch 579:  Error = 50.966954
# Epoch 580:  Error = 50.967011
# Epoch 581:  Error = 50.967068
# Epoch 582:  Error = 50.967124
# Epoch 583:  Error = 50.967181
# Epoch 584:  Error = 50.967237
# Epoch 585:  Error = 50.967293
# Epoch 586:  Error = 50.967349
# Epoch 587:  Error = 50.967405
# Epoch 588:  Error = 50.967460
# Epoch 589:  Error = 50.967515
# Epoch 590:  Error = 50.967571
# Epoch 591:  Error = 50.967625
# Epoch 592:  Error = 50.967680
# Epoch 593:  Error = 50.967735
# Epoch 594:  Error = 50.967789
# Epoch 595:  Error = 50.967843
# Epoch 596:  Error = 50.967897
# Epoch 597:  Error = 50.967951
# Epoch 598:  Error = 50.968005
# Epoch 599:  Error = 50.968058
# Epoch 600:  Error = 50.968112
# Epoch 601:  Error = 50.968165
# Epoch 602:  Error = 50.968218
# Epoch 603:  Error = 50.968270
# Epoch 604:  Error = 50.968323
# Epoch 605:  Error = 50.968375
# Epoch 606:  Error = 50.968428
# Epoch 607:  Error = 50.968480
# Epoch 608:  Error = 50.968531
# Epoch 609:  Error = 50.968583
# Epoch 610:  Error = 50.968635
# Epoch 611:  Error = 50.968686
# Epoch 612:  Error = 50.968737
# Epoch 613:  Error = 50.968788
# Epoch 614:  Error = 50.968839
# Epoch 615:  Error = 50.968890
# Epoch 616:  Error = 50.968941
# Epoch 617:  Error = 50.968991
# Epoch 618:  Error = 50.969041
# Epoch 619:  Error = 50.969091
# Epoch 620:  Error = 50.969141
# Epoch 621:  Error = 50.969191
# Epoch 622:  Error = 50.969240
# Epoch 623:  Error = 50.969290
# Epoch 624:  Error = 50.969339
# Epoch 625:  Error = 50.969388
# Epoch 626:  Error = 50.969437
# Epoch 627:  Error = 50.969486
# Epoch 628:  Error = 50.969534
# Epoch 629:  Error = 50.969583
# Epoch 630:  Error = 50.969631
# Epoch 631:  Error = 50.969679
# Epoch 632:  Error = 50.969727
# Epoch 633:  Error = 50.969775
# Epoch 634:  Error = 50.969823
# Epoch 635:  Error = 50.969871
# Epoch 636:  Error = 50.969918
# Epoch 637:  Error = 50.969965
# Epoch 638:  Error = 50.970012
# Epoch 639:  Error = 50.970059
# Epoch 640:  Error = 50.970106
# Epoch 641:  Error = 50.970153
# Epoch 642:  Error = 50.970199
# Epoch 643:  Error = 50.970246
# Epoch 644:  Error = 50.970292
# Epoch 645:  Error = 50.970338
# Epoch 646:  Error = 50.970384
# Epoch 647:  Error = 50.970430
# Epoch 648:  Error = 50.970476
# Epoch 649:  Error = 50.970521
# Epoch 650:  Error = 50.970566
# Epoch 651:  Error = 50.970612
# Epoch 652:  Error = 50.970657
# Epoch 653:  Error = 50.970702
# Epoch 654:  Error = 50.970747
# Epoch 655:  Error = 50.970791
# Epoch 656:  Error = 50.970836
# Epoch 657:  Error = 50.970880
# Epoch 658:  Error = 50.970925
# Epoch 659:  Error = 50.970969
# Epoch 660:  Error = 50.971013
# Epoch 661:  Error = 50.971057
# Epoch 662:  Error = 50.971100
# Epoch 663:  Error = 50.971144
# Epoch 664:  Error = 50.971188
# Epoch 665:  Error = 50.971231
# Epoch 666:  Error = 50.971274
# Epoch 667:  Error = 50.971317
# Epoch 668:  Error = 50.971360
# Epoch 669:  Error = 50.971403
# Epoch 670:  Error = 50.971446
# Epoch 671:  Error = 50.971488
# Epoch 672:  Error = 50.971531
# Epoch 673:  Error = 50.971573
# Epoch 674:  Error = 50.971615
# Epoch 675:  Error = 50.971657
# Epoch 676:  Error = 50.971699
# Epoch 677:  Error = 50.971741
# Epoch 678:  Error = 50.971783
# Epoch 679:  Error = 50.971824
# Epoch 680:  Error = 50.971866
# Epoch 681:  Error = 50.971907
# Epoch 682:  Error = 50.971949
# Epoch 683:  Error = 50.971990
# Epoch 684:  Error = 50.972031
# Epoch 685:  Error = 50.972071
# Epoch 686:  Error = 50.972112
# Epoch 687:  Error = 50.972153
# Epoch 688:  Error = 50.972193
# Epoch 689:  Error = 50.972234
# Epoch 690:  Error = 50.972274
# Epoch 691:  Error = 50.972314
# Epoch 692:  Error = 50.972354
# Epoch 693:  Error = 50.972394
# Epoch 694:  Error = 50.972434
# Epoch 695:  Error = 50.972474
# Epoch 696:  Error = 50.972513
# Epoch 697:  Error = 50.972553
# Epoch 698:  Error = 50.972592
# Epoch 699:  Error = 50.972631
# Epoch 700:  Error = 50.972670
# Epoch 701:  Error = 50.972709
# Epoch 702:  Error = 50.972748
# Epoch 703:  Error = 50.972787
# Epoch 704:  Error = 50.972826
# Epoch 705:  Error = 50.972864
# Epoch 706:  Error = 50.972903
# Epoch 707:  Error = 50.972941
# Epoch 708:  Error = 50.972979
# Epoch 709:  Error = 50.973018
# Epoch 710:  Error = 50.973056
# Epoch 711:  Error = 50.973093
# Epoch 712:  Error = 50.973131
# Epoch 713:  Error = 50.973169
# Epoch 714:  Error = 50.973207
# Epoch 715:  Error = 50.973244
# Epoch 716:  Error = 50.973281
# Epoch 717:  Error = 50.973319
# Epoch 718:  Error = 50.973356
# Epoch 719:  Error = 50.973393
# Epoch 720:  Error = 50.973430
# Epoch 721:  Error = 50.973467
# Epoch 722:  Error = 50.973504
# Epoch 723:  Error = 50.973540
# Epoch 724:  Error = 50.973577
# Epoch 725:  Error = 50.973613
# Epoch 726:  Error = 50.973650
# Epoch 727:  Error = 50.973686
# Epoch 728:  Error = 50.973722
# Epoch 729:  Error = 50.973758
# Epoch 730:  Error = 50.973794
# Epoch 731:  Error = 50.973830
# Epoch 732:  Error = 50.973866
# Epoch 733:  Error = 50.973902
# Epoch 734:  Error = 50.973937
# Epoch 735:  Error = 50.973973
# Epoch 736:  Error = 50.974008
# Epoch 737:  Error = 50.974043
# Epoch 738:  Error = 50.974079
# Epoch 739:  Error = 50.974114
# Epoch 740:  Error = 50.974149
# Epoch 741:  Error = 50.974184
# Epoch 742:  Error = 50.974218
# Epoch 743:  Error = 50.974253
# Epoch 744:  Error = 50.974288
# Epoch 745:  Error = 50.974322
# Epoch 746:  Error = 50.974357
# Epoch 747:  Error = 50.974391
# Epoch 748:  Error = 50.974425
# Epoch 749:  Error = 50.974459
# Epoch 750:  Error = 50.974494
# Epoch 751:  Error = 50.974527
# Epoch 752:  Error = 50.974561
# Epoch 753:  Error = 50.974595
# Epoch 754:  Error = 50.974629
# Epoch 755:  Error = 50.974663
# Epoch 756:  Error = 50.974696
# Epoch 757:  Error = 50.974730
# Epoch 758:  Error = 50.974763
# Epoch 759:  Error = 50.974796
# Epoch 760:  Error = 50.974829
# Epoch 761:  Error = 50.974862
# Epoch 762:  Error = 50.974895
# Epoch 763:  Error = 50.974928
# Epoch 764:  Error = 50.974961
# Epoch 765:  Error = 50.974994
# Epoch 766:  Error = 50.975027
# Epoch 767:  Error = 50.975059
# Epoch 768:  Error = 50.975092
# Epoch 769:  Error = 50.975124
# Epoch 770:  Error = 50.975156
# Epoch 771:  Error = 50.975189
# Epoch 772:  Error = 50.975221
# Epoch 773:  Error = 50.975253
# Epoch 774:  Error = 50.975285
# Epoch 775:  Error = 50.975317
# Epoch 776:  Error = 50.975349
# Epoch 777:  Error = 50.975380
# Epoch 778:  Error = 50.975412
# Epoch 779:  Error = 50.975444
# Epoch 780:  Error = 50.975475
# Epoch 781:  Error = 50.975507
# Epoch 782:  Error = 50.975538
# Epoch 783:  Error = 50.975569
# Epoch 784:  Error = 50.975600
# Epoch 785:  Error = 50.975631
# Epoch 786:  Error = 50.975662
# Epoch 787:  Error = 50.975693
# Epoch 788:  Error = 50.975724
# Epoch 789:  Error = 50.975755
# Epoch 790:  Error = 50.975786
# Epoch 791:  Error = 50.975816
# Epoch 792:  Error = 50.975847
# Epoch 793:  Error = 50.975877
# Epoch 794:  Error = 50.975908
# Epoch 795:  Error = 50.975938
# Epoch 796:  Error = 50.975968
# Epoch 797:  Error = 50.975999
# Epoch 798:  Error = 50.976029
# Epoch 799:  Error = 50.976059
# Epoch 800:  Error = 50.976089
# Epoch 801:  Error = 50.976118
# Epoch 802:  Error = 50.976148
# Epoch 803:  Error = 50.976178
# Epoch 804:  Error = 50.976208
# Epoch 805:  Error = 50.976237
# Epoch 806:  Error = 50.976267
# Epoch 807:  Error = 50.976296
# Epoch 808:  Error = 50.976325
# Epoch 809:  Error = 50.976355
# Epoch 810:  Error = 50.976384
# Epoch 811:  Error = 50.976413
# Epoch 812:  Error = 50.976442
# Epoch 813:  Error = 50.976471
# Epoch 814:  Error = 50.976500
# Epoch 815:  Error = 50.976529
# Epoch 816:  Error = 50.976558
# Epoch 817:  Error = 50.976586
# Epoch 818:  Error = 50.976615
# Epoch 819:  Error = 50.976644
# Epoch 820:  Error = 50.976672
# Epoch 821:  Error = 50.976701
# Epoch 822:  Error = 50.976729
# Epoch 823:  Error = 50.976757
# Epoch 824:  Error = 50.976785
# Epoch 825:  Error = 50.976814
# Epoch 826:  Error = 50.976842
# Epoch 827:  Error = 50.976870
# Epoch 828:  Error = 50.976898
# Epoch 829:  Error = 50.976926
# Epoch 830:  Error = 50.976953
# Epoch 831:  Error = 50.976981
# Epoch 832:  Error = 50.977009
# Epoch 833:  Error = 50.977036
# Epoch 834:  Error = 50.977064
# Epoch 835:  Error = 50.977091
# Epoch 836:  Error = 50.977119
# Epoch 837:  Error = 50.977146
# Epoch 838:  Error = 50.977173
# Epoch 839:  Error = 50.977201
# Epoch 840:  Error = 50.977228
# Epoch 841:  Error = 50.977255
# Epoch 842:  Error = 50.977282
# Epoch 843:  Error = 50.977309
# Epoch 844:  Error = 50.977336
# Epoch 845:  Error = 50.977363
# Epoch 846:  Error = 50.977389
# Epoch 847:  Error = 50.977416
# Epoch 848:  Error = 50.977443
# Epoch 849:  Error = 50.977469
# Epoch 850:  Error = 50.977496
# Epoch 851:  Error = 50.977522
# Epoch 852:  Error = 50.977549
# Epoch 9497:  Error = 50.997986
# Epoch 9498:  Error = 50.997987
# Epoch 9499:  Error = 50.997987
# Epoch 9500:  Error = 50.997987
# Epoch 9501:  Error = 50.997987
# Epoch 9502:  Error = 50.997987
# Epoch 9503:  Error = 50.997988
# Epoch 9504:  Error = 50.997988
# Epoch 9505:  Error = 50.997988
# Epoch 9506:  Error = 50.997988
# Epoch 9507:  Error = 50.997989
# Epoch 9508:  Error = 50.997989
# Epoch 9509:  Error = 50.997989
# Epoch 9510:  Error = 50.997989
# Epoch 9511:  Error = 50.997989
# Epoch 9512:  Error = 50.997990
# Epoch 9513:  Error = 50.997990
# Epoch 9514:  Error = 50.997990
# Epoch 9515:  Error = 50.997990
# Epoch 9516:  Error = 50.997990
# Epoch 9517:  Error = 50.997991
# Epoch 9518:  Error = 50.997991
# Epoch 9519:  Error = 50.997991
# Epoch 9520:  Error = 50.997991
# Epoch 9521:  Error = 50.997991
# Epoch 9522:  Error = 50.997992
# Epoch 9523:  Error = 50.997992
# Epoch 9524:  Error = 50.997992
# Epoch 9525:  Error = 50.997992
# Epoch 9526:  Error = 50.997993
# Epoch 9527:  Error = 50.997993
# Epoch 9528:  Error = 50.997993
# Epoch 9529:  Error = 50.997993
# Epoch 9530:  Error = 50.997993
# Epoch 9531:  Error = 50.997994
# Epoch 9532:  Error = 50.997994
# Epoch 9533:  Error = 50.997994
# Epoch 9534:  Error = 50.997994
# Epoch 9535:  Error = 50.997994
# Epoch 9536:  Error = 50.997995
# Epoch 9537:  Error = 50.997995
# Epoch 9538:  Error = 50.997995
# Epoch 9539:  Error = 50.997995
# Epoch 9540:  Error = 50.997995
# Epoch 9541:  Error = 50.997996
# Epoch 9542:  Error = 50.997996
# Epoch 9543:  Error = 50.997996
# Epoch 9544:  Error = 50.997996
# Epoch 9545:  Error = 50.997997
# Epoch 9546:  Error = 50.997997
# Epoch 9547:  Error = 50.997997
# Epoch 9548:  Error = 50.997997
# Epoch 9549:  Error = 50.997997
# Epoch 9550:  Error = 50.997998
# Epoch 9551:  Error = 50.997998
# Epoch 9552:  Error = 50.997998
# Epoch 9553:  Error = 50.997998
# Epoch 9554:  Error = 50.997998
# Epoch 9555:  Error = 50.997999
# Epoch 9556:  Error = 50.997999
# Epoch 9557:  Error = 50.997999
# Epoch 9558:  Error = 50.997999
# Epoch 9559:  Error = 50.997999
# Epoch 9560:  Error = 50.998000
# Epoch 9561:  Error = 50.998000
# Epoch 9562:  Error = 50.998000
# Epoch 9563:  Error = 50.998000
# Epoch 9564:  Error = 50.998001
# Epoch 9565:  Error = 50.998001
# Epoch 9566:  Error = 50.998001
# Epoch 9567:  Error = 50.998001
# Epoch 9568:  Error = 50.998001
# Epoch 9569:  Error = 50.998002
# Epoch 9570:  Error = 50.998002
# Epoch 9571:  Error = 50.998002
# Epoch 9572:  Error = 50.998002
# Epoch 9573:  Error = 50.998002
# Epoch 9574:  Error = 50.998003
# Epoch 9575:  Error = 50.998003
# Epoch 9576:  Error = 50.998003
# Epoch 9577:  Error = 50.998003
# Epoch 9578:  Error = 50.998003
# Epoch 9579:  Error = 50.998004
# Epoch 9580:  Error = 50.998004
# Epoch 9581:  Error = 50.998004
# Epoch 9582:  Error = 50.998004
# Epoch 9583:  Error = 50.998004
# Epoch 9584:  Error = 50.998005
# Epoch 9585:  Error = 50.998005
# Epoch 9586:  Error = 50.998005
# Epoch 9587:  Error = 50.998005
# Epoch 9588:  Error = 50.998006
# Epoch 9589:  Error = 50.998006
# Epoch 9590:  Error = 50.998006
# Epoch 9591:  Error = 50.998006
# Epoch 9592:  Error = 50.998006
# Epoch 9593:  Error = 50.998007
# Epoch 9594:  Error = 50.998007
# Epoch 9595:  Error = 50.998007
# Epoch 9596:  Error = 50.998007
# Epoch 9597:  Error = 50.998007
# Epoch 9598:  Error = 50.998008
# Epoch 9599:  Error = 50.998008
# Epoch 9600:  Error = 50.998008
# Epoch 9601:  Error = 50.998008
# Epoch 9602:  Error = 50.998008
# Epoch 9603:  Error = 50.998009
# Epoch 9604:  Error = 50.998009
# Epoch 9605:  Error = 50.998009
# Epoch 9606:  Error = 50.998009
# Epoch 9607:  Error = 50.998009
# Epoch 9608:  Error = 50.998010
# Epoch 9609:  Error = 50.998010
# Epoch 9610:  Error = 50.998010
# Epoch 9611:  Error = 50.998010
# Epoch 9612:  Error = 50.998011
# Epoch 9613:  Error = 50.998011
# Epoch 9614:  Error = 50.998011
# Epoch 9615:  Error = 50.998011
# Epoch 9616:  Error = 50.998011
# Epoch 9617:  Error = 50.998012
# Epoch 9618:  Error = 50.998012
# Epoch 9619:  Error = 50.998012
# Epoch 9620:  Error = 50.998012
# Epoch 9621:  Error = 50.998012
# Epoch 9622:  Error = 50.998013
# Epoch 9623:  Error = 50.998013
# Epoch 9624:  Error = 50.998013
# Epoch 9625:  Error = 50.998013
# Epoch 9626:  Error = 50.998013
# Epoch 9627:  Error = 50.998014
# Epoch 9628:  Error = 50.998014
# Epoch 9629:  Error = 50.998014
# Epoch 9630:  Error = 50.998014
# Epoch 9631:  Error = 50.998014
# Epoch 9632:  Error = 50.998015
# Epoch 9633:  Error = 50.998015
# Epoch 9634:  Error = 50.998015
# Epoch 9635:  Error = 50.998015
# Epoch 9636:  Error = 50.998015
# Epoch 9637:  Error = 50.998016
# Epoch 9638:  Error = 50.998016
# Epoch 9639:  Error = 50.998016
# Epoch 9640:  Error = 50.998016
# Epoch 9641:  Error = 50.998016
# Epoch 9642:  Error = 50.998017
# Epoch 9643:  Error = 50.998017
# Epoch 9644:  Error = 50.998017
# Epoch 9645:  Error = 50.998017
# Epoch 9646:  Error = 50.998018
# Epoch 9647:  Error = 50.998018
# Epoch 9648:  Error = 50.998018
# Epoch 9649:  Error = 50.998018
# Epoch 9650:  Error = 50.998018
# Epoch 9651:  Error = 50.998019
# Epoch 9652:  Error = 50.998019
# Epoch 9653:  Error = 50.998019
# Epoch 9654:  Error = 50.998019
# Epoch 9655:  Error = 50.998019
# Epoch 9656:  Error = 50.998020
# Epoch 9657:  Error = 50.998020
# Epoch 9658:  Error = 50.998020
# Epoch 9659:  Error = 50.998020
# Epoch 9660:  Error = 50.998020
# Epoch 9661:  Error = 50.998021
# Epoch 9662:  Error = 50.998021
# Epoch 9663:  Error = 50.998021
# Epoch 9664:  Error = 50.998021
# Epoch 9665:  Error = 50.998021
# Epoch 9666:  Error = 50.998022
# Epoch 9667:  Error = 50.998022
# Epoch 9668:  Error = 50.998022
# Epoch 9669:  Error = 50.998022
# Epoch 9670:  Error = 50.998022
# Epoch 9671:  Error = 50.998023
# Epoch 9672:  Error = 50.998023
# Epoch 9673:  Error = 50.998023
# Epoch 9674:  Error = 50.998023
# Epoch 9675:  Error = 50.998023
# Epoch 9676:  Error = 50.998024
# Epoch 9677:  Error = 50.998024
# Epoch 9678:  Error = 50.998024
# Epoch 9679:  Error = 50.998024
# Epoch 9680:  Error = 50.998024
# Epoch 9681:  Error = 50.998025
# Epoch 9682:  Error = 50.998025
# Epoch 9683:  Error = 50.998025
# Epoch 9684:  Error = 50.998025
# Epoch 9685:  Error = 50.998026
# Epoch 9686:  Error = 50.998026
# Epoch 9687:  Error = 50.998026
# Epoch 9688:  Error = 50.998026
# Epoch 9689:  Error = 50.998026
# Epoch 9690:  Error = 50.998027
# Epoch 9691:  Error = 50.998027
# Epoch 9692:  Error = 50.998027
# Epoch 9693:  Error = 50.998027
# Epoch 9694:  Error = 50.998027
# Epoch 9695:  Error = 50.998028
# Epoch 9696:  Error = 50.998028
# Epoch 9697:  Error = 50.998028
# Epoch 9698:  Error = 50.998028
# Epoch 9699:  Error = 50.998028
# Epoch 9700:  Error = 50.998029
# Epoch 9701:  Error = 50.998029
# Epoch 9702:  Error = 50.998029
# Epoch 9703:  Error = 50.998029
# Epoch 9704:  Error = 50.998029
# Epoch 9705:  Error = 50.998030
# Epoch 9706:  Error = 50.998030
# Epoch 9707:  Error = 50.998030
# Epoch 9708:  Error = 50.998030
# Epoch 9709:  Error = 50.998030
# Epoch 9710:  Error = 50.998031
# Epoch 9711:  Error = 50.998031
# Epoch 9712:  Error = 50.998031
# Epoch 9713:  Error = 50.998031
# Epoch 9714:  Error = 50.998031
# Epoch 9715:  Error = 50.998032
# Epoch 9716:  Error = 50.998032
# Epoch 9717:  Error = 50.998032
# Epoch 9718:  Error = 50.998032
# Epoch 9719:  Error = 50.998032
# Epoch 9720:  Error = 50.998033
# Epoch 9721:  Error = 50.998033
# Epoch 9722:  Error = 50.998033
# Epoch 9723:  Error = 50.998033
# Epoch 9724:  Error = 50.998033
# Epoch 9725:  Error = 50.998034
# Epoch 9726:  Error = 50.998034
# Epoch 9727:  Error = 50.998034
# Epoch 9728:  Error = 50.998034
# Epoch 9729:  Error = 50.998034
# Epoch 9730:  Error = 50.998035
# Epoch 9731:  Error = 50.998035
# Epoch 9732:  Error = 50.998035
# Epoch 9733:  Error = 50.998035
# Epoch 9734:  Error = 50.998035
# Epoch 9735:  Error = 50.998036
# Epoch 9736:  Error = 50.998036
# Epoch 9737:  Error = 50.998036
# Epoch 9738:  Error = 50.998036
# Epoch 9739:  Error = 50.998036
# Epoch 9740:  Error = 50.998037
# Epoch 9741:  Error = 50.998037
# Epoch 9742:  Error = 50.998037
# Epoch 9743:  Error = 50.998037
# Epoch 9744:  Error = 50.998037
# Epoch 9745:  Error = 50.998038
# Epoch 9746:  Error = 50.998038
# Epoch 9747:  Error = 50.998038
# Epoch 9748:  Error = 50.998038
# Epoch 9749:  Error = 50.998038
# Epoch 9750:  Error = 50.998039
# Epoch 9751:  Error = 50.998039
# Epoch 9752:  Error = 50.998039
# Epoch 9753:  Error = 50.998039
# Epoch 9754:  Error = 50.998039
# Epoch 9755:  Error = 50.998040
# Epoch 9756:  Error = 50.998040
# Epoch 9757:  Error = 50.998040
# Epoch 9758:  Error = 50.998040
# Epoch 9759:  Error = 50.998040
# Epoch 9760:  Error = 50.998041
# Epoch 9761:  Error = 50.998041
# Epoch 9762:  Error = 50.998041
# Epoch 9763:  Error = 50.998041
# Epoch 9764:  Error = 50.998041
# Epoch 9765:  Error = 50.998042
# Epoch 9766:  Error = 50.998042
# Epoch 9767:  Error = 50.998042
# Epoch 9768:  Error = 50.998042
# Epoch 9769:  Error = 50.998042
# Epoch 9770:  Error = 50.998043
# Epoch 9771:  Error = 50.998043
# Epoch 9772:  Error = 50.998043
# Epoch 9773:  Error = 50.998043
# Epoch 9774:  Error = 50.998043
# Epoch 9775:  Error = 50.998044
# Epoch 9776:  Error = 50.998044
# Epoch 9777:  Error = 50.998044
# Epoch 9778:  Error = 50.998044
# Epoch 9779:  Error = 50.998044
# Epoch 9780:  Error = 50.998045
# Epoch 9781:  Error = 50.998045
# Epoch 9782:  Error = 50.998045
# Epoch 9783:  Error = 50.998045
# Epoch 9784:  Error = 50.998045
# Epoch 9785:  Error = 50.998046
# Epoch 9786:  Error = 50.998046
# Epoch 9787:  Error = 50.998046
# Epoch 9788:  Error = 50.998046
# Epoch 9789:  Error = 50.998046
# Epoch 9790:  Error = 50.998047
# Epoch 9791:  Error = 50.998047
# Epoch 9792:  Error = 50.998047
# Epoch 9793:  Error = 50.998047
# Epoch 9794:  Error = 50.998047
# Epoch 9795:  Error = 50.998048
# Epoch 9796:  Error = 50.998048
# Epoch 9797:  Error = 50.998048
# Epoch 9798:  Error = 50.998048
# Epoch 9799:  Error = 50.998048
# Epoch 9800:  Error = 50.998049
# Epoch 9801:  Error = 50.998049
# Epoch 9802:  Error = 50.998049
# Epoch 9803:  Error = 50.998049
# Epoch 9804:  Error = 50.998049
# Epoch 9805:  Error = 50.998050
# Epoch 9806:  Error = 50.998050
# Epoch 9807:  Error = 50.998050
# Epoch 9808:  Error = 50.998050
# Epoch 9809:  Error = 50.998050
# Epoch 9810:  Error = 50.998051
# Epoch 9811:  Error = 50.998051
# Epoch 9812:  Error = 50.998051
# Epoch 9813:  Error = 50.998051
# Epoch 9814:  Error = 50.998051
# Epoch 9815:  Error = 50.998052
# Epoch 9816:  Error = 50.998052
# Epoch 9817:  Error = 50.998052
# Epoch 9818:  Error = 50.998052
# Epoch 9819:  Error = 50.998052
# Epoch 9820:  Error = 50.998053
# Epoch 9821:  Error = 50.998053
# Epoch 9822:  Error = 50.998053
# Epoch 9823:  Error = 50.998053
# Epoch 9824:  Error = 50.998053
# Epoch 9825:  Error = 50.998054
# Epoch 9826:  Error = 50.998054
# Epoch 9827:  Error = 50.998054
# Epoch 9828:  Error = 50.998054
# Epoch 9829:  Error = 50.998054
# Epoch 9830:  Error = 50.998055
# Epoch 9831:  Error = 50.998055
# Epoch 9832:  Error = 50.998055
# Epoch 9833:  Error = 50.998055
# Epoch 9834:  Error = 50.998055
# Epoch 9835:  Error = 50.998056
# Epoch 9836:  Error = 50.998056
# Epoch 9837:  Error = 50.998056
# Epoch 9838:  Error = 50.998056
# Epoch 9839:  Error = 50.998056
# Epoch 9840:  Error = 50.998057
# Epoch 9841:  Error = 50.998057
# Epoch 9842:  Error = 50.998057
# Epoch 9843:  Error = 50.998057
# Epoch 9844:  Error = 50.998057
# Epoch 9845:  Error = 50.998058
# Epoch 9846:  Error = 50.998058
# Epoch 9847:  Error = 50.998058
# Epoch 9848:  Error = 50.998058
# Epoch 9849:  Error = 50.998058
# Epoch 9850:  Error = 50.998059
# Epoch 9851:  Error = 50.998059
# Epoch 9852:  Error = 50.998059
# Epoch 9853:  Error = 50.998059
# Epoch 9854:  Error = 50.998059
# Epoch 9855:  Error = 50.998060
# Epoch 9856:  Error = 50.998060
# Epoch 9857:  Error = 50.998060
# Epoch 9858:  Error = 50.998060
# Epoch 9859:  Error = 50.998060
# Epoch 9860:  Error = 50.998061
# Epoch 9861:  Error = 50.998061
# Epoch 9862:  Error = 50.998061
# Epoch 9863:  Error = 50.998061
# Epoch 9864:  Error = 50.998061
# Epoch 9865:  Error = 50.998062
# Epoch 9866:  Error = 50.998062
# Epoch 9867:  Error = 50.998062
# Epoch 9868:  Error = 50.998062
# Epoch 9869:  Error = 50.998062
# Epoch 9870:  Error = 50.998063
# Epoch 9871:  Error = 50.998063
# Epoch 9872:  Error = 50.998063
# Epoch 9873:  Error = 50.998063
# Epoch 9874:  Error = 50.998063
# Epoch 9875:  Error = 50.998063
# Epoch 9876:  Error = 50.998064
# Epoch 9877:  Error = 50.998064
# Epoch 9878:  Error = 50.998064
# Epoch 9879:  Error = 50.998064
# Epoch 9880:  Error = 50.998064
# Epoch 9881:  Error = 50.998065
# Epoch 9882:  Error = 50.998065
# Epoch 9883:  Error = 50.998065
# Epoch 9884:  Error = 50.998065
# Epoch 9885:  Error = 50.998065
# Epoch 9886:  Error = 50.998066
# Epoch 9887:  Error = 50.998066
# Epoch 9888:  Error = 50.998066
# Epoch 9889:  Error = 50.998066
# Epoch 9890:  Error = 50.998066
# Epoch 9891:  Error = 50.998067
# Epoch 9892:  Error = 50.998067
# Epoch 9893:  Error = 50.998067
# Epoch 9894:  Error = 50.998067
# Epoch 9895:  Error = 50.998067
# Epoch 9896:  Error = 50.998068
# Epoch 9897:  Error = 50.998068
# Epoch 9898:  Error = 50.998068
# Epoch 9899:  Error = 50.998068
# Epoch 9900:  Error = 50.998068
# Epoch 9901:  Error = 50.998069
# Epoch 9902:  Error = 50.998069
# Epoch 9903:  Error = 50.998069
# Epoch 9904:  Error = 50.998069
# Epoch 9905:  Error = 50.998069
# Epoch 9906:  Error = 50.998070
# Epoch 9907:  Error = 50.998070
# Epoch 9908:  Error = 50.998070
# Epoch 9909:  Error = 50.998070
# Epoch 9910:  Error = 50.998070
# Epoch 9911:  Error = 50.998071
# Epoch 9912:  Error = 50.998071
# Epoch 9913:  Error = 50.998071
# Epoch 9914:  Error = 50.998071
# Epoch 9915:  Error = 50.998071
# Epoch 9916:  Error = 50.998071
# Epoch 9917:  Error = 50.998072
# Epoch 9918:  Error = 50.998072
# Epoch 9919:  Error = 50.998072
# Epoch 9920:  Error = 50.998072
# Epoch 9921:  Error = 50.998072
# Epoch 9922:  Error = 50.998073
# Epoch 9923:  Error = 50.998073
# Epoch 9924:  Error = 50.998073
# Epoch 9925:  Error = 50.998073
# Epoch 9926:  Error = 50.998073
# Epoch 9927:  Error = 50.998074
# Epoch 9928:  Error = 50.998074
# Epoch 9929:  Error = 50.998074
# Epoch 9930:  Error = 50.998074
# Epoch 9931:  Error = 50.998074
# Epoch 9932:  Error = 50.998075
# Epoch 9933:  Error = 50.998075
# Epoch 9934:  Error = 50.998075
# Epoch 9935:  Error = 50.998075
# Epoch 9936:  Error = 50.998075
# Epoch 9937:  Error = 50.998076
# Epoch 9938:  Error = 50.998076
# Epoch 9939:  Error = 50.998076
# Epoch 9940:  Error = 50.998076
# Epoch 9941:  Error = 50.998076
# Epoch 9942:  Error = 50.998077
# Epoch 9943:  Error = 50.998077
# Epoch 9944:  Error = 50.998077
# Epoch 9945:  Error = 50.998077
# Epoch 9946:  Error = 50.998077
# Epoch 9947:  Error = 50.998078
# Epoch 9948:  Error = 50.998078
# Epoch 9949:  Error = 50.998078
# Epoch 9950:  Error = 50.998078
# Epoch 9951:  Error = 50.998078
# Epoch 9952:  Error = 50.998078
# Epoch 9953:  Error = 50.998079
# Epoch 9954:  Error = 50.998079
# Epoch 9955:  Error = 50.998079
# Epoch 9956:  Error = 50.998079
# Epoch 9957:  Error = 50.998079
# Epoch 9958:  Error = 50.998080
# Epoch 9959:  Error = 50.998080
# Epoch 9960:  Error = 50.998080
# Epoch 9961:  Error = 50.998080
# Epoch 9962:  Error = 50.998080
# Epoch 9963:  Error = 50.998081
# Epoch 9964:  Error = 50.998081
# Epoch 9965:  Error = 50.998081
# Epoch 9966:  Error = 50.998081
# Epoch 9967:  Error = 50.998081
# Epoch 9968:  Error = 50.998082
# Epoch 9969:  Error = 50.998082
# Epoch 9970:  Error = 50.998082
# Epoch 9971:  Error = 50.998082
# Epoch 9972:  Error = 50.998082
# Epoch 9973:  Error = 50.998083
# Epoch 9974:  Error = 50.998083
# Epoch 9975:  Error = 50.998083
# Epoch 9976:  Error = 50.998083
# Epoch 9977:  Error = 50.998083
# Epoch 9978:  Error = 50.998083
# Epoch 9979:  Error = 50.998084
# Epoch 9980:  Error = 50.998084
# Epoch 9981:  Error = 50.998084
# Epoch 9982:  Error = 50.998084
# Epoch 9983:  Error = 50.998084
# Epoch 9984:  Error = 50.998085
# Epoch 9985:  Error = 50.998085
# Epoch 9986:  Error = 50.998085
# Epoch 9987:  Error = 50.998085
# Epoch 9988:  Error = 50.998085
# Epoch 9989:  Error = 50.998086
# Epoch 9990:  Error = 50.998086
# Epoch 9991:  Error = 50.998086
# Epoch 9992:  Error = 50.998086
# Epoch 9993:  Error = 50.998086
# Epoch 9994:  Error = 50.998087
# Epoch 9995:  Error = 50.998087
# Epoch 9996:  Error = 50.998087
# Epoch 9997:  Error = 50.998087
# Epoch 9998:  Error = 50.998087
# Epoch 9999:  Error = 50.998088

# %% [markdown]
# ## Using Pytorch to enjoy life : OPTIONNEL
#
# Up to now, we have been writing every operations by ourselves (in order to better understand the mathematics behind NN). However, there exists of course some simplifying libraries that provide large simplifications to this question.
#
# One of the most powerful and complete library of this sort is `Pytorch`, which has been developed for several years (even prior to the recent boom of deep learning). `Pytorch` provides a large set of pre-coded layers, but also **computational graphs** and **autograd**, which are very powerful paradigms allowing to define complex operators and automatically taking derivatives.
#
# ### Defining our network
#
# When building neural networks we frequently think of arranging the computation into layers, some of which have learnable parameters which will be optimized during learning. In `PyTorch`, the `nn` package provides higher-level abstractions over raw computational graphs that are useful for building neural networks. The `nn` package defines a set of `Modules`, which are roughly equivalent to neural network layers. A `Module` receives input `Tensors` and computes output `Tensors`, but may also hold internal state such as `Tensors` containing learnable parameters. The nn package also defines a set of useful loss functions that are commonly used when training neural networks.
#
# In the following example, we use the `nn` package to show how easy it is to instantiate our previous three-layers network

# %%
import torch
# Define the input dimensions
in_size = 1000
# Number of neurons in a layer
hidden_size = 100
# Output (target) dimension
output_size = 10
# Use the nn package to define our model and loss function.
model = torch.nn.Sequential(
    torch.nn.Linear(in_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, hidden_size),
    torch.nn.ReLU(),
    torch.nn.Linear(hidden_size, output_size),
    torch.nn.Softmax(dim=1)
)

# %% [markdown]
# ### Optimizing the network
#
# Up to this point we have updated the weights of our models by manually performing the gradient descent algorithm (changing the parameters vectors). Although this is not a huge burden for simple optimization algorithms like stochastic gradient descent, in practice we often train neural networks using more sophisticated optimizers like AdaGrad, RMSProp or Adam (that we will see later in this course)
#
# The `optim` package in PyTorch abstracts the idea of an optimization algorithm and provides implementations of commonly used optimization algorithms, and greatly simplfies the training loop associated with training a neural network.
#
# For the sake of presentation we will use random inputs $\mathbf{x}$ that should be matched with random outputs $\mathbf{y}$

# %%
batch_size = 64
# Create random Tensors to hold inputs and outputs
x = torch.randn(N, D_in)
y = torch.randn(N, D_out)

# %% [markdown]
# In the following example we optimize the model using the Adam algorithm provided by the `optim` package, based on a `MSE` loss.

# %%
# Learning rate
learning_rate = 1e-4
# Loss function that we will use
loss_fn = torch.nn.MSELoss(reduction='sum')
# Optimizer to fit the weights of the network
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
for t in range(500):
    # Forward pass: compute predicted y by passing x to the model.
    y_pred = model(x)
    # Compute the loss.
    loss = loss_fn(y_pred, y)
    # Before the backward pass, zero all of the network gradients
    optimizer.zero_grad()
    # Backward pass: compute gradient of the loss with respect to parameters
    loss.backward()
    # Calling the step function to update the parameters
    optimizer.step()

# %% [markdown]
# ## Using Pytorch to classify audio
#
# Now that we know the main components of `Pytorch` to define and optimize networks, your assignement is to define a complete classification problem from audio data, by relying on this toolbox
#
# ***
#
# **Exercise**
#
#   1. Use `Pytorch` to define a model for audio classification
#   2. Import the audio features dataset and check that your model produces an output
#   3. Write the optimization loop (think carefully about the _loss function_
#   4. As previously, change the set of features to assess their different accuracies
#   5. Think of how you could use more complex features (time series, audio, STFT) to classify your data
#
# ***

# %%
######################
# YOUR CODE GOES HERE
######################
